# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd
from PIL import Image
import os
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# <h1>1. Подготовка данных</h1>

# %%
df = pd.read_csv('all_letters_info.csv')
label_to_letter = df[['label', 'letter']].drop_duplicates().set_index('label')['letter'].to_dict()
letter_to_label = df[['label', 'letter']].drop_duplicates().set_index('letter')['label'].to_dict()
print(label_to_letter)
print(letter_to_label)
df.head()
# Out:
# {1: 'а', 2: 'б', 3: 'в', 4: 'г', 5: 'д', 6: 'е', 7: 'ё', 8: 'ж', 9: 'з', 10: 'и', 11: 'й', 12: 'к', 13: 'л', 14: 'м', 15: 'н', 16: 'о', 17: 'п', 18: 'р', 19: 'с', 20: 'т', 21: 'у', 22: 'ф', 23: 'х', 24: 'ц', 25: 'ч', 26: 'ш', 27: 'щ', 28: 'ъ', 29: 'ы', 30: 'ь', 31: 'э', 32: 'ю', 33: 'я'}
# {'а': 1, 'б': 2, 'в': 3, 'г': 4, 'д': 5, 'е': 6, 'ё': 7, 'ж': 8, 'з': 9, 'и': 10, 'й': 11, 'к': 12, 'л': 13, 'м': 14, 'н': 15, 'о': 16, 'п': 17, 'р': 18, 'с': 19, 'т': 20, 'у': 21, 'ф': 22, 'х': 23, 'ц': 24, 'ч': 25, 'ш': 26, 'щ': 27, 'ъ': 28, 'ы': 29, 'ь': 30, 'э': 31, 'ю': 32, 'я': 33}
#   letter  label       file  background
# 0      а      1  01_01.png           0
# 1      а      1  01_02.png           0
# 2      а      1  01_03.png           0
# 3      а      1  01_04.png           0
# 4      а      1  01_05.png           0

# %%
images_folder_path = 'all_letters_image/all_letters_image/'

X, Y = [], []

for _, row in df.iterrows():
    image_path = os.path.join(images_folder_path, row['file'])
    
    with Image.open(image_path) as img:
        img = img.convert('L')
        
        img = img.resize((32, 32))
        
        img_flattened = np.array(img).flatten()
        
        X.append(img_flattened)
        Y.append(row['label'])

X = np.array(X)
y = np.array(Y)


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %% [markdown]
# <h1>2. Random Forest Classifier</h1>

# %%
def test_model(model, X_train, X, y_train, y, NN = False, only_train = False):
    def test_case(X_to_predict, Y_to_predict):
        predictions = model.predict(X_to_predict)
        #[print(prediction) for prediction in predictions]
        if NN: predictions = np.argmax(predictions, axis=1)
        print(predictions)
        #print(len(set(predictions)))
        incorrect_indices = np.where(predictions != Y_to_predict)[0]
        for i in incorrect_indices:
            print(f"Prediction: {label_to_letter[predictions[i]]}, Actual letter: {label_to_letter[Y_to_predict[i]]}")
        
        print(f"Accuracy: {accuracy_score(Y_to_predict, predictions)}, My Accuracy: {(len(X_to_predict) - len(incorrect_indices))/len(X_to_predict)}")


    print("Training data test")
    test_case(X_train, y_train)
    
    if not(only_train):
        print("Full data test")
        test_case(X, y)

# %%
clf = RandomForestClassifier(n_estimators=100, random_state=42)
clf.fit(X_train, y_train)
test_model(clf, X_train, X, y_train, y)
# Out:
# Training data test
# 33
# []
# Accuracy: 1.0, My Accuracy: 1.0
# Full data test
# 33
# [    8    14    27    31    35    41    47    63    99   101   102   113
#    135   167   168   169   173   177   181   184   217   218   247   280
#    284   286   290   299   304   311   315   327   353   357   360   379
#    385   410   411   431   465   468   473   476   487   511   533   538
#    542   568   586   592   608   624   683   696   708   720   732   735
#    736   747   749   772   794   795   811   833   836   862   868   872
#    900   902   903   907   914   927   937   970   977   993  1010  1022
#   1026  1034  1039  1053  1061  1078  1083  1087  1107  1111  1114  1121
#   1139  1175  1197  1199  1213  1225  1247  1253  1261  1270  1310  1320
#   1350  1351  1358  1368  1370  1372  1373  1393  1398  1418  1433  1453
#   1454  1475  1482  1483  1488  1489  1493  1516  1530  1533  1534  1547
#   1562  1575  1579  1580  1586  1593  1598  1599  1606  1611  1617  1623
#   1624  1634  1655  1659  1662  1683  1688  1697  1713  1722  1730  1739
#   1740  1743  1744  1766  1769  1795  1807  1880  1923  1957  1989  2002
#   2009  2012  2019  2021  2034  2039  2054  2081  2085  2099  2112  2119
#   2124  2128  2133  2144  2145  2150  2157  2177  2183  2184  2189  2214
#   2215  2286  2301  2308  2325  2404  2405  2425  2439  2442  2455  2477
#   2485  2501  2519  2525  2531  2589  2595  2596  2609  2626  2628  2629
#   2704  2714  2715  2766  2769  2771  2791  2796  2864  2884  2910  2919
#   2924  2928  2954  2974  2992  2996  3000  3014  3017  3021  3025  3035
#   3043  3045  3058  3063  3069  3076  3077  3079  3107  3146  3187  3248
#   3299  3322  3429  3437  3448  3455  3469  3488  3508  3509  3559  3562
#   3570  3585  3616  3651  3668  3678  3680  3717  3745  3753  3780  3784
#   3794  3842  3860  3889  3910  3946  3948  4003  4040  4064  4069  4075
#   4096  4097  4100  4106  4128  4129  4147  4149  4165  4184  4202  4215
#   4231  4233  4245  4246  4269  4291  4295  4303  4325  4338  4344  4353
#   4359  4365  4393  4394  4395  4398  4410  4441  4462  4469  4475  4506
#   4513  4519  4520  4540  4580  4600  4606  4618  4629  4684  4685  4692
#   4702  4746  4801  4822  4863  4870  4884  4889  4923  4948  4952  4959
#   4965  4991  5001  5019  5044  5049  5062  5082  5156  5199  5212  5219
#   5220  5224  5257  5286  5312  5324  5328  5340  5350  5353  5371  5430
#   5437  5479  5504  5511  5514  5527  5549  5556  5562  5563  5566  5595
#   5597  5601  5605  5609  5617  5620  5627  5632  5654  5678  5681  5692
#   5712  5716  5719  5729  5768  5773  5786  5787  5822  5846  5928  5937
#   5952  5987  5990  5993  6000  6005  6013  6041  6061  6070  6077  6081
#   6083  6098  6107  6118  6128  6134  6145  6148  6152  6173  6201  6211
#   6225  6258  6277  6292  6298  6319  6341  6343  6347  6388  6412  6417
#   6459  6478  6491  6515  6561  6597  6606  6611  6624  6630  6634  6651
#   6654  6658  6662  6695  6713  6729  6740  6753  6755  6757  6786  6791
#   6794  6817  6835  6842  6844  6861  6875  6884  6890  6896  6904  6927
#   6950  6952  6955  6964  6969  7042  7046  7050  7051  7145  7150  7199
#   7200  7210  7219  7222  7223  7231  7307  7318  7333  7375  7393  7414
#   7416  7434  7456  7460  7506  7510  7524  7525  7529  7535  7541  7593
#   7603  7623  7625  7631  7637  7660  7672  7681  7691  7706  7712  7726
#   7728  7732  7748  7749  7767  7773  7800  7840  7853  7877  7882  7883
#   7886  7890  7907  7908  7937  7985  8025  8028  8048  8062  8066  8101
#   8109  8116  8124  8137  8140  8145  8163  8169  8171  8192  8200  8236
#   8237  8256  8265  8267  8280  8294  8296  8317  8421  8422  8454  8459
#   8460  8471  8495  8518  8539  8557  8563  8565  8572  8589  8593  8598
#   8607  8674  8677  8703  8704  8726  8742  8768  8769  8779  8790  8805
#   8814  8856  8862  8959  8962  8971  8975  8977  8985  8993  8994  9000
#   9016  9050  9059  9071  9073  9075  9088  9118  9156  9186  9220  9228
#   9237  9248  9282  9292  9351  9366  9379  9393  9420  9432  9443  9450
#   9460  9468  9484  9486  9525  9526  9530  9541  9573  9577  9592  9594
#   9624  9661  9664  9666  9668  9675  9682  9697  9706  9720  9736  9737
#   9753  9767  9808  9812  9814  9837  9868  9871  9881  9894  9896  9931
#   9933  9934  9937  9939  9952  9960  9966  9967  9972  9980  9993 10020
#  10042 10043 10054 10105 10125 10164 10203 10220 10234 10275 10284 10305
#  10316 10318 10363 10375 10397 10413 10415 10436 10458 10465 10466 10474
#  10483 10496 10501 10525 10564 10597 10610 10626 10669 10673 10692 10710
#  10744 10762 10768 10786 10794 10798 10799 10803 10806 10810 10827 10847
#  10880 10881 10886 10887 10895 10898 10904 10926 10949 10950 11056 11092
#  11100 11170 11190 11233 11236 11255 11256 11265 11268 11270 11285 11395
#  11400 11413 11480 11490 11509 11646 11668 11843 11848 11874 11951 11989
#  12109 12171 12195 12228 12240 12270 12280 12337 12403 12446 12455 12485
#  12500 12507 12511 12518 12544 12548 12595 12596 12623 12624 12628 12649
#  12667 12689 12698 12733 12750 12773 12783 13018 13042 13075 13088 13108
#  13142 13209 13222 13264 13279 13303 13304 13320 13321 13335 13347 13364
#  13420 13494 13498 13512 13513 13516 13524 13527 13570 13591 13639 13644
#  13671 13699 13710 13715 13723 13770 13787 13824 13831 13841 13864 13891
#  13928 13940 13941 13948 13962 13972 13978 13999 14002 14026 14033 14057
#  14060 14065 14074 14093 14104 14110 14135 14142 14144]
# Accuracy: 0.939323467230444, My Accuracy: 0.939323467230444

# %% [markdown]
# <h1>3. Многослойный перцептрон (с полносвязными слоями)</h1>

# %%
print(X_train)
X_train.shape
#X_train = X_train / 255.0
# Out:
# [[171 169 164 ... 170 171 164]
#  [155 157 151 ... 161 167 166]
#  [119 111 124 ... 145 131 128]
#  ...
#  [177 177 177 ... 171 171 170]
#  [115 114 111 ... 116 115 113]
#  [114 113 113 ... 107 105 105]]
# (12771, 1024)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=2)
X_train_normalized = X_train / 255.0
X_normalized = X / 255.0

#Мб услоднить модель?
fully_connected_model = Sequential([
    Dense(1024, input_shape=(1024,), activation='relu'),
    BatchNormalization(),
    #Dropout(0.25),
    Dense(512, activation='relu'),
    BatchNormalization(),
    #Dropout(0.25),
    Dense(256, activation='relu'),
    BatchNormalization(),
    #Dropout(0.1),
    Dense(128, activation='relu'),
    BatchNormalization(),
    #Dropout(0.1),
    Dense(34, activation='softmax')
])

fully_connected_model.compile(optimizer=Adam(learning_rate=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
history = fully_connected_model.fit(X_train_normalized, y_train, epochs=50, batch_size=64, validation_split=0.2)
test_model(fully_connected_model, X_train_normalized, X_normalized, y_train, y, NN=True)
# Out:
# Epoch 1/50
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 160/160 [==============================] - 6s 22ms/step - loss: 3.1597 - accuracy: 0.1412 - val_loss: 3.7880 - val_accuracy: 0.0513
# Epoch 2/50
# 160/160 [==============================] - 3s 20ms/step - loss: 2.7932 - accuracy: 0.2106 - val_loss: 8.8352 - val_accuracy: 0.0262
# Epoch 3/50
# 160/160 [==============================] - 3s 21ms/step - loss: 2.6289 - accuracy: 0.2511 - val_loss: 10.2985 - val_accuracy: 0.0270
# Epoch 4/50
# 160/160 [==============================] - 3s 20ms/step - loss: 2.5093 - accuracy: 0.2863 - val_loss: 8.5908 - val_accuracy: 0.0305
# Epoch 5/50
# 160/160 [==============================] - 3s 20ms/step - loss: 2.3707 - accuracy: 0.3179 - val_loss: 18.0489 - val_accuracy: 0.0254
# Epoch 6/50
# 160/160 [==============================] - 3s 20ms/step - loss: 2.2918 - accuracy: 0.3319 - val_loss: 17.6704 - val_accuracy: 0.0297
# Epoch 7/50
# 160/160 [==============================] - 3s 20ms/step - loss: 2.1250 - accuracy: 0.3775 - val_loss: 7.7806 - val_accuracy: 0.0403
# Epoch 8/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.9906 - accuracy: 0.4096 - val_loss: 12.3880 - val_accuracy: 0.0387
# Epoch 9/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.9289 - accuracy: 0.4319 - val_loss: 3.5357 - val_accuracy: 0.1750
# Epoch 10/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.7911 - accuracy: 0.4734 - val_loss: 3.9596 - val_accuracy: 0.1667
# Epoch 11/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.7002 - accuracy: 0.4941 - val_loss: 4.3213 - val_accuracy: 0.1585
# Epoch 12/50
# 160/160 [==============================] - 3s 19ms/step - loss: 1.6556 - accuracy: 0.5007 - val_loss: 5.4384 - val_accuracy: 0.1068
# Epoch 13/50
# 160/160 [==============================] - 3s 19ms/step - loss: 1.5837 - accuracy: 0.5229 - val_loss: 4.3015 - val_accuracy: 0.1757
# Epoch 14/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.5263 - accuracy: 0.5345 - val_loss: 4.3806 - val_accuracy: 0.1804
# Epoch 15/50
# 160/160 [==============================] - 3s 21ms/step - loss: 1.4751 - accuracy: 0.5543 - val_loss: 4.4424 - val_accuracy: 0.1393
# Epoch 16/50
# 160/160 [==============================] - 3s 21ms/step - loss: 1.4181 - accuracy: 0.5699 - val_loss: 4.6751 - val_accuracy: 0.1307
# Epoch 17/50
# 160/160 [==============================] - 3s 21ms/step - loss: 1.3795 - accuracy: 0.5797 - val_loss: 4.1847 - val_accuracy: 0.1577
# Epoch 18/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.3480 - accuracy: 0.5890 - val_loss: 3.4792 - val_accuracy: 0.2243
# Epoch 19/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.2885 - accuracy: 0.6017 - val_loss: 4.5970 - val_accuracy: 0.1436
# Epoch 20/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.2650 - accuracy: 0.6056 - val_loss: 4.2094 - val_accuracy: 0.1624
# Epoch 21/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.2417 - accuracy: 0.6181 - val_loss: 2.8264 - val_accuracy: 0.2939
# Epoch 22/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.2077 - accuracy: 0.6259 - val_loss: 4.8377 - val_accuracy: 0.1961
# Epoch 23/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.1616 - accuracy: 0.6366 - val_loss: 4.4600 - val_accuracy: 0.1879
# Epoch 24/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.1195 - accuracy: 0.6479 - val_loss: 2.9979 - val_accuracy: 0.2963
# Epoch 25/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.1091 - accuracy: 0.6546 - val_loss: 5.4331 - val_accuracy: 0.1542
# Epoch 26/50
# 160/160 [==============================] - 3s 19ms/step - loss: 1.1086 - accuracy: 0.6467 - val_loss: 5.4482 - val_accuracy: 0.1765
# Epoch 27/50
# 160/160 [==============================] - 3s 21ms/step - loss: 1.0600 - accuracy: 0.6671 - val_loss: 3.1754 - val_accuracy: 0.3237
# Epoch 28/50
# 160/160 [==============================] - 3s 21ms/step - loss: 1.0159 - accuracy: 0.6754 - val_loss: 4.9208 - val_accuracy: 0.2031
# Epoch 29/50
# 160/160 [==============================] - 3s 20ms/step - loss: 1.0131 - accuracy: 0.6809 - val_loss: 3.8346 - val_accuracy: 0.2806
# Epoch 30/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.9605 - accuracy: 0.6919 - val_loss: 3.6753 - val_accuracy: 0.2470
# Epoch 31/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.9566 - accuracy: 0.6968 - val_loss: 5.9825 - val_accuracy: 0.1746
# Epoch 32/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9160 - accuracy: 0.7138 - val_loss: 4.2301 - val_accuracy: 0.2470
# Epoch 33/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.9154 - accuracy: 0.7045 - val_loss: 5.1988 - val_accuracy: 0.1573
# Epoch 34/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.8644 - accuracy: 0.7236 - val_loss: 3.8228 - val_accuracy: 0.2955
# Epoch 35/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.8562 - accuracy: 0.7256 - val_loss: 5.1902 - val_accuracy: 0.1800
# Epoch 36/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.8479 - accuracy: 0.7309 - val_loss: 5.0782 - val_accuracy: 0.1562
# Epoch 37/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.8197 - accuracy: 0.7347 - val_loss: 4.6246 - val_accuracy: 0.1933
# Epoch 38/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.8157 - accuracy: 0.7345 - val_loss: 5.6461 - val_accuracy: 0.1750
# Epoch 39/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.7817 - accuracy: 0.7473 - val_loss: 4.5225 - val_accuracy: 0.2211
# Epoch 40/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.7526 - accuracy: 0.7604 - val_loss: 3.5408 - val_accuracy: 0.3084
# Epoch 41/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.7508 - accuracy: 0.7554 - val_loss: 4.3946 - val_accuracy: 0.2403
# Epoch 42/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.7396 - accuracy: 0.7635 - val_loss: 2.9291 - val_accuracy: 0.3906
# Epoch 43/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.7471 - accuracy: 0.7614 - val_loss: 3.1451 - val_accuracy: 0.3667
# Epoch 44/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.7246 - accuracy: 0.7711 - val_loss: 3.0304 - val_accuracy: 0.3706
# Epoch 45/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.7137 - accuracy: 0.7694 - val_loss: 3.7465 - val_accuracy: 0.3061
# Epoch 46/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.7002 - accuracy: 0.7807 - val_loss: 6.6603 - val_accuracy: 0.1573
# Epoch 47/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.7008 - accuracy: 0.7753 - val_loss: 5.3721 - val_accuracy: 0.2235
# Epoch 48/50
# 160/160 [==============================] - 3s 20ms/step - loss: 0.6511 - accuracy: 0.7907 - val_loss: 4.5367 - val_accuracy: 0.2411
# Epoch 49/50
# 160/160 [==============================] - 3s 21ms/step - loss: 0.6749 - accuracy: 0.7816 - val_loss: 4.1587 - val_accuracy: 0.2853
# Epoch 50/50
# 160/160 [==============================] - 3s 22ms/step - loss: 0.6288 - accuracy: 0.8008 - val_loss: 5.2787 - val_accuracy: 0.2227
# Training data test
# 400/400 [==============================] - 2s 4ms/step
# 33
# [    1     2     3 ... 12768 12769 12770]
# Accuracy: 0.2505676924281575, My Accuracy: 0.2505676924281575
# Full data test
# 444/444 [==============================] - 1s 3ms/step
# 33
# [    0     1     2 ... 14176 14181 14182]
# Accuracy: 0.24601832276250882, My Accuracy: 0.24601832276250882

# %% [markdown]
# <h1>4. Сверточная нейронная сеть на исходных данных (с разными вариантами архитектуры).</h1>

# %%
X_train_reshaped = X_train_normalized.reshape((-1, 32, 32, 1))

# %% [markdown]
# <h3>Simple CNN</h3>

# %%
simple_CNN = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 1)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(34, activation='softmax')
])
# Out:
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\layers\pooling\max_pooling2d.py:161: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.

# %%
simple_CNN.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

simple_CNN_history = simple_CNN.fit(X_train_reshaped, y_train, epochs=10, batch_size=64, validation_split=0.2)
# Out:
# WARNING:tensorflow:From c:\Users\79270\Desktop\Zubr\enviroments\ml\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/10
# 160/160 [==============================] - 3s 16ms/step - loss: 3.5135 - accuracy: 0.0356 - val_loss: 3.4873 - val_accuracy: 0.0564
# Epoch 2/10
# 160/160 [==============================] - 2s 15ms/step - loss: 3.4328 - accuracy: 0.0542 - val_loss: 3.3895 - val_accuracy: 0.0481
# Epoch 3/10
# 160/160 [==============================] - 2s 15ms/step - loss: 3.3627 - accuracy: 0.0680 - val_loss: 3.3596 - val_accuracy: 0.0759
# Epoch 4/10
# 160/160 [==============================] - 2s 14ms/step - loss: 3.3204 - accuracy: 0.0930 - val_loss: 3.2955 - val_accuracy: 0.0896
# Epoch 5/10
# 160/160 [==============================] - 2s 14ms/step - loss: 3.2257 - accuracy: 0.1165 - val_loss: 3.1777 - val_accuracy: 0.1084
# Epoch 6/10
# 160/160 [==============================] - 2s 15ms/step - loss: 3.0714 - accuracy: 0.1451 - val_loss: 3.0244 - val_accuracy: 0.1491
# Epoch 7/10
# 160/160 [==============================] - 2s 14ms/step - loss: 2.9350 - accuracy: 0.1734 - val_loss: 2.9076 - val_accuracy: 0.1800
# Epoch 8/10
# 160/160 [==============================] - 2s 14ms/step - loss: 2.8385 - accuracy: 0.2003 - val_loss: 2.8344 - val_accuracy: 0.2016
# Epoch 9/10
# 160/160 [==============================] - 2s 14ms/step - loss: 2.7788 - accuracy: 0.2108 - val_loss: 2.7904 - val_accuracy: 0.2204
# Epoch 10/10
# 160/160 [==============================] - 2s 14ms/step - loss: 2.7189 - accuracy: 0.2301 - val_loss: 2.7341 - val_accuracy: 0.2160

# %% [markdown]
# <h3>Как мы можем видеть, простая CNN не в состонии развить лучшую стратегию классификации, чем распознавать каждое изображение, как одну и ту же букву. Конечно, можно было бы попытаться настроить гиперпараметры, количество эпох в целях улучшеиня точности классификации, но рациональнее и целесообразнее производить тонкую настройку гиперпараметров на изначально более сложной архитектуре.</h3>

# %% [markdown]
# <h3>Более сложная CNN</h3>

# %%
more_complex_CNN = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 1)),
    #BatchNormalization(),
    MaxPooling2D((2, 2)),
    Conv2D(40, (3, 3), activation='relu'),
    #BatchNormalization(),
    MaxPooling2D((2, 2)),
    Conv2D(50, (3, 3), activation='relu'),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(34, activation='softmax')
])

#X_train_reshaped

# %%
more_complex_CNN.compile(optimizer=Adam(learning_rate=0.001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

more_complex_CNN_history = more_complex_CNN.fit(X_train_reshaped, y_train, epochs=10, batch_size=128, validation_split=0.2)
test_model(more_complex_CNN, X_train_reshaped, X, y_train, y, NN=True, only_train=True)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 4s 34ms/step - loss: 3.5205 - accuracy: 0.0304 - val_loss: 3.5096 - val_accuracy: 0.0290
# Epoch 2/10
# 80/80 [==============================] - 3s 32ms/step - loss: 3.4643 - accuracy: 0.0416 - val_loss: 3.4084 - val_accuracy: 0.0521
# Epoch 3/10
# 80/80 [==============================] - 2s 31ms/step - loss: 3.3835 - accuracy: 0.0658 - val_loss: 3.3619 - val_accuracy: 0.0806
# Epoch 4/10
# 80/80 [==============================] - 2s 30ms/step - loss: 3.2272 - accuracy: 0.1088 - val_loss: 3.0340 - val_accuracy: 0.1366
# Epoch 5/10
# 80/80 [==============================] - 2s 30ms/step - loss: 2.8115 - accuracy: 0.2051 - val_loss: 2.6898 - val_accuracy: 0.2200
# Epoch 6/10
# 80/80 [==============================] - 2s 30ms/step - loss: 2.5722 - accuracy: 0.2668 - val_loss: 2.5470 - val_accuracy: 0.2689
# Epoch 7/10
# 80/80 [==============================] - 2s 30ms/step - loss: 2.4318 - accuracy: 0.3102 - val_loss: 2.4342 - val_accuracy: 0.3104
# Epoch 8/10
# 80/80 [==============================] - 2s 30ms/step - loss: 2.3137 - accuracy: 0.3473 - val_loss: 2.2999 - val_accuracy: 0.3354
# Epoch 9/10
# 80/80 [==============================] - 2s 30ms/step - loss: 2.2163 - accuracy: 0.3761 - val_loss: 2.1741 - val_accuracy: 0.3730
# Epoch 10/10
# 80/80 [==============================] - 3s 31ms/step - loss: 2.1244 - accuracy: 0.4026 - val_loss: 2.0898 - val_accuracy: 0.4023
# Training data test
# 400/400 [==============================] - 2s 5ms/step
# 33
# [    1     2     3 ... 12767 12768 12770]
# Accuracy: 0.41367159971811135, My Accuracy: 0.41367159971811135

# %% [markdown]
# <h3>Как мы видим, добавление большего количества слоев и нейронов на каждом слое улучшило точность классификации, добавив больше эпох мы бы получили достойную(по метрике accuracy) модель</h3>

# %% [markdown]
# <h3>Модель с наиболее сложной архитектурой(арбитрарно)</h3>

# %%
complex_CNN = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 1)),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu'),
    Flatten(),
    #Dropout(0.5),
    Dense(128, activation='relu'),
    #Dropout(0.5),
    Dense(34, activation='softmax')
])

# %%
complex_CNN.compile(optimizer=Adam(learning_rate=0.001),
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

complex_CNN_history = complex_CNN.fit(X_train_reshaped, y_train, epochs=10, batch_size=128, validation_split=0.2)
test_model(complex_CNN, X_train_reshaped, X, y_train, y, NN=True, only_train=True)
# Out:
# Epoch 1/10
# 80/80 [==============================] - 11s 119ms/step - loss: 2.1049 - accuracy: 0.4253 - val_loss: 0.8561 - val_accuracy: 0.7546
# Epoch 2/10
# 80/80 [==============================] - 11s 137ms/step - loss: 0.5232 - accuracy: 0.8437 - val_loss: 0.6802 - val_accuracy: 0.8004
# Epoch 3/10
# 80/80 [==============================] - 11s 133ms/step - loss: 0.3722 - accuracy: 0.8897 - val_loss: 0.6498 - val_accuracy: 0.8149
# Epoch 4/10
# 80/80 [==============================] - 13s 160ms/step - loss: 0.2999 - accuracy: 0.9129 - val_loss: 0.6259 - val_accuracy: 0.8215
# Epoch 5/10
# 80/80 [==============================] - 14s 180ms/step - loss: 0.2728 - accuracy: 0.9225 - val_loss: 0.6135 - val_accuracy: 0.8223
# Epoch 6/10
# 80/80 [==============================] - 11s 133ms/step - loss: 0.2472 - accuracy: 0.9284 - val_loss: 0.6268 - val_accuracy: 0.8153
# Epoch 7/10
# 80/80 [==============================] - 10s 122ms/step - loss: 0.2452 - accuracy: 0.9282 - val_loss: 0.6132 - val_accuracy: 0.8290
# Epoch 8/10
# 80/80 [==============================] - 11s 133ms/step - loss: 0.2143 - accuracy: 0.9411 - val_loss: 0.6155 - val_accuracy: 0.8282
# Epoch 9/10
# 80/80 [==============================] - 9s 115ms/step - loss: 0.2025 - accuracy: 0.9411 - val_loss: 0.6031 - val_accuracy: 0.8282
# Epoch 10/10
# 80/80 [==============================] - 10s 119ms/step - loss: 0.1952 - accuracy: 0.9443 - val_loss: 0.6232 - val_accuracy: 0.8344
# Training data test
# 400/400 [==============================] - 6s 15ms/step
# [25 16 10 ...  5  6 32]
# Prediction: и, Actual letter: н
# Prediction: в, Actual letter: ь
# Prediction: л, Actual letter: п
# Prediction: ж, Actual letter: ш
# Prediction: ж, Actual letter: к
# Prediction: н, Actual letter: к
# Prediction: г, Actual letter: е
# Prediction: ё, Actual letter: б
# Prediction: н, Actual letter: ж
# Prediction: х, Actual letter: я
# Prediction: е, Actual letter: ь
# Prediction: ы, Actual letter: и
# Prediction: щ, Actual letter: ш
# Prediction: п, Actual letter: а
# Prediction: е, Actual letter: с
# Prediction: ч, Actual letter: г
# Prediction: ы, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: н, Actual letter: ы
# Prediction: д, Actual letter: у
# Prediction: е, Actual letter: ё
# Prediction: к, Actual letter: н
# Prediction: э, Actual letter: ф
# Prediction: г, Actual letter: ю
# Prediction: щ, Actual letter: а
# Prediction: з, Actual letter: ъ
# Prediction: з, Actual letter: ф
# Prediction: э, Actual letter: я
# Prediction: д, Actual letter: у
# Prediction: ж, Actual letter: и
# Prediction: ы, Actual letter: и
# Prediction: ж, Actual letter: и
# Prediction: н, Actual letter: и
# Prediction: м, Actual letter: ш
# Prediction: у, Actual letter: ч
# Prediction: з, Actual letter: э
# Prediction: ъ, Actual letter: ч
# Prediction: о, Actual letter: п
# Prediction: к, Actual letter: ю
# Prediction: г, Actual letter: х
# Prediction: я, Actual letter: н
# Prediction: ь, Actual letter: в
# Prediction: ж, Actual letter: и
# Prediction: ь, Actual letter: с
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: ж
# Prediction: о, Actual letter: ф
# Prediction: ы, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: о
# Prediction: л, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: а
# Prediction: я, Actual letter: в
# Prediction: к, Actual letter: н
# Prediction: я, Actual letter: а
# Prediction: ы, Actual letter: ю
# Prediction: а, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: а
# Prediction: э, Actual letter: я
# Prediction: в, Actual letter: ё
# Prediction: б, Actual letter: ъ
# Prediction: ч, Actual letter: ъ
# Prediction: ж, Actual letter: т
# Prediction: з, Actual letter: ч
# Prediction: д, Actual letter: у
# Prediction: в, Actual letter: ъ
# Prediction: ж, Actual letter: х
# Prediction: х, Actual letter: а
# Prediction: д, Actual letter: в
# Prediction: с, Actual letter: й
# Prediction: в, Actual letter: ь
# Prediction: ж, Actual letter: ы
# Prediction: ф, Actual letter: х
# Prediction: з, Actual letter: ч
# Prediction: ф, Actual letter: щ
# Prediction: х, Actual letter: а
# Prediction: д, Actual letter: ь
# Prediction: й, Actual letter: в
# Prediction: ь, Actual letter: ъ
# Prediction: л, Actual letter: р
# Prediction: и, Actual letter: п
# Prediction: ж, Actual letter: н
# Prediction: ъ, Actual letter: ц
# Prediction: ж, Actual letter: и
# Prediction: л, Actual letter: а
# Prediction: я, Actual letter: д
# Prediction: ж, Actual letter: ш
# Prediction: э, Actual letter: ч
# Prediction: в, Actual letter: к
# Prediction: з, Actual letter: о
# Prediction: д, Actual letter: ф
# Prediction: к, Actual letter: н
# Prediction: д, Actual letter: о
# Prediction: и, Actual letter: й
# Prediction: щ, Actual letter: ц
# Prediction: м, Actual letter: ю
# Prediction: д, Actual letter: ф
# Prediction: г, Actual letter: н
# Prediction: в, Actual letter: к
# Prediction: т, Actual letter: п
# Prediction: ы, Actual letter: к
# Prediction: н, Actual letter: и
# Prediction: о, Actual letter: а
# Prediction: л, Actual letter: я
# Prediction: и, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: х, Actual letter: и
# Prediction: я, Actual letter: а
# Prediction: ж, Actual letter: н
# Prediction: з, Actual letter: ъ
# Prediction: е, Actual letter: о
# Prediction: ч, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: з, Actual letter: т
# Prediction: а, Actual letter: ш
# Prediction: й, Actual letter: ъ
# Prediction: в, Actual letter: ь
# Prediction: й, Actual letter: о
# Prediction: м, Actual letter: и
# Prediction: я, Actual letter: л
# Prediction: ж, Actual letter: ы
# Prediction: н, Actual letter: к
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: д, Actual letter: ф
# Prediction: к, Actual letter: и
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: я, Actual letter: м
# Prediction: и, Actual letter: н
# Prediction: е, Actual letter: ё
# Prediction: щ, Actual letter: ш
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: ф
# Prediction: г, Actual letter: т
# Prediction: д, Actual letter: у
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: р
# Prediction: д, Actual letter: ъ
# Prediction: у, Actual letter: р
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: м
# Prediction: ф, Actual letter: ы
# Prediction: ч, Actual letter: г
# Prediction: з, Actual letter: о
# Prediction: с, Actual letter: а
# Prediction: д, Actual letter: ф
# Prediction: ы, Actual letter: а
# Prediction: я, Actual letter: ю
# Prediction: к, Actual letter: п
# Prediction: з, Actual letter: д
# Prediction: д, Actual letter: о
# Prediction: л, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: к
# Prediction: ь, Actual letter: ы
# Prediction: д, Actual letter: о
# Prediction: м, Actual letter: ш
# Prediction: к, Actual letter: х
# Prediction: ё, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: я, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: п, Actual letter: к
# Prediction: т, Actual letter: п
# Prediction: ж, Actual letter: п
# Prediction: и, Actual letter: н
# Prediction: с, Actual letter: а
# Prediction: к, Actual letter: е
# Prediction: к, Actual letter: п
# Prediction: х, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: з
# Prediction: э, Actual letter: ы
# Prediction: щ, Actual letter: ш
# Prediction: ь, Actual letter: а
# Prediction: д, Actual letter: з
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: х
# Prediction: з, Actual letter: д
# Prediction: ж, Actual letter: н
# Prediction: л, Actual letter: м
# Prediction: ф, Actual letter: т
# Prediction: л, Actual letter: м
# Prediction: л, Actual letter: м
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: н
# Prediction: с, Actual letter: е
# Prediction: ф, Actual letter: р
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: с
# Prediction: ц, Actual letter: ш
# Prediction: щ, Actual letter: т
# Prediction: у, Actual letter: з
# Prediction: н, Actual letter: и
# Prediction: э, Actual letter: ч
# Prediction: ж, Actual letter: ы
# Prediction: д, Actual letter: ъ
# Prediction: з, Actual letter: ф
# Prediction: х, Actual letter: г
# Prediction: ж, Actual letter: п
# Prediction: з, Actual letter: д
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: н
# Prediction: я, Actual letter: ч
# Prediction: я, Actual letter: м
# Prediction: ж, Actual letter: т
# Prediction: о, Actual letter: а
# Prediction: е, Actual letter: с
# Prediction: л, Actual letter: а
# Prediction: к, Actual letter: п
# Prediction: е, Actual letter: х
# Prediction: з, Actual letter: ц
# Prediction: ж, Actual letter: н
# Prediction: ь, Actual letter: а
# Prediction: е, Actual letter: н
# Prediction: с, Actual letter: о
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: ё
# Prediction: ь, Actual letter: в
# Prediction: у, Actual letter: д
# Prediction: е, Actual letter: с
# Prediction: ъ, Actual letter: ш
# Prediction: к, Actual letter: ь
# Prediction: ц, Actual letter: п
# Prediction: ы, Actual letter: н
# Prediction: ь, Actual letter: в
# Prediction: ф, Actual letter: р
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: ю
# Prediction: в, Actual letter: п
# Prediction: э, Actual letter: я
# Prediction: ф, Actual letter: ю
# Prediction: х, Actual letter: а
# Prediction: я, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: ъ, Actual letter: в
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: г
# Prediction: ф, Actual letter: к
# Prediction: ь, Actual letter: а
# Prediction: м, Actual letter: ж
# Prediction: ф, Actual letter: ж
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: л
# Prediction: м, Actual letter: ш
# Prediction: ш, Actual letter: т
# Prediction: к, Actual letter: и
# Prediction: м, Actual letter: ш
# Prediction: л, Actual letter: м
# Prediction: л, Actual letter: и
# Prediction: е, Actual letter: г
# Prediction: щ, Actual letter: ш
# Prediction: п, Actual letter: а
# Prediction: с, Actual letter: е
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: ф
# Prediction: х, Actual letter: а
# Prediction: п, Actual letter: т
# Prediction: ж, Actual letter: щ
# Prediction: ъ, Actual letter: ч
# Prediction: а, Actual letter: о
# Prediction: в, Actual letter: ч
# Prediction: ы, Actual letter: п
# Prediction: в, Actual letter: а
# Prediction: е, Actual letter: ь
# Prediction: о, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: ц, Actual letter: ш
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ш
# Prediction: ы, Actual letter: о
# Prediction: ж, Actual letter: т
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: и
# Prediction: я, Actual letter: а
# Prediction: г, Actual letter: ч
# Prediction: я, Actual letter: н
# Prediction: л, Actual letter: м
# Prediction: г, Actual letter: п
# Prediction: м, Actual letter: и
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: а
# Prediction: б, Actual letter: й
# Prediction: ь, Actual letter: ч
# Prediction: ш, Actual letter: а
# Prediction: г, Actual letter: а
# Prediction: у, Actual letter: ё
# Prediction: щ, Actual letter: ш
# Prediction: у, Actual letter: щ
# Prediction: к, Actual letter: н
# Prediction: щ, Actual letter: ш
# Prediction: я, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: п, Actual letter: т
# Prediction: р, Actual letter: к
# Prediction: в, Actual letter: г
# Prediction: з, Actual letter: а
# Prediction: с, Actual letter: п
# Prediction: е, Actual letter: а
# Prediction: х, Actual letter: и
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: п
# Prediction: у, Actual letter: ф
# Prediction: х, Actual letter: я
# Prediction: д, Actual letter: ь
# Prediction: и, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: к, Actual letter: п
# Prediction: х, Actual letter: и
# Prediction: д, Actual letter: у
# Prediction: я, Actual letter: а
# Prediction: ч, Actual letter: ъ
# Prediction: ч, Actual letter: т
# Prediction: щ, Actual letter: ш
# Prediction: ж, Actual letter: н
# Prediction: к, Actual letter: п
# Prediction: ж, Actual letter: н
# Prediction: ч, Actual letter: с
# Prediction: к, Actual letter: п
# Prediction: к, Actual letter: ю
# Prediction: д, Actual letter: б
# Prediction: в, Actual letter: ч
# Prediction: и, Actual letter: г
# Prediction: я, Actual letter: и
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: с
# Prediction: д, Actual letter: г
# Prediction: х, Actual letter: ж
# Prediction: д, Actual letter: з
# Prediction: с, Actual letter: а
# Prediction: е, Actual letter: п
# Prediction: в, Actual letter: й
# Prediction: н, Actual letter: ы
# Prediction: к, Actual letter: п
# Prediction: с, Actual letter: з
# Prediction: м, Actual letter: т
# Prediction: г, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ш
# Prediction: е, Actual letter: к
# Prediction: е, Actual letter: к
# Prediction: л, Actual letter: й
# Prediction: д, Actual letter: в
# Prediction: ж, Actual letter: м
# Prediction: з, Actual letter: у
# Prediction: ж, Actual letter: м
# Prediction: д, Actual letter: у
# Prediction: д, Actual letter: р
# Prediction: а, Actual letter: ш
# Prediction: г, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: г, Actual letter: ъ
# Prediction: е, Actual letter: г
# Prediction: ч, Actual letter: ц
# Prediction: у, Actual letter: ъ
# Prediction: х, Actual letter: у
# Prediction: ш, Actual letter: щ
# Prediction: э, Actual letter: я
# Prediction: л, Actual letter: м
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: о
# Prediction: п, Actual letter: т
# Prediction: к, Actual letter: н
# Prediction: ж, Actual letter: н
# Prediction: л, Actual letter: т
# Prediction: ж, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: э, Actual letter: ь
# Prediction: е, Actual letter: ю
# Prediction: д, Actual letter: з
# Prediction: и, Actual letter: ш
# Prediction: г, Actual letter: ш
# Prediction: п, Actual letter: к
# Prediction: я, Actual letter: п
# Prediction: п, Actual letter: г
# Prediction: л, Actual letter: и
# Prediction: в, Actual letter: ё
# Prediction: щ, Actual letter: ю
# Prediction: м, Actual letter: ш
# Prediction: м, Actual letter: ш
# Prediction: я, Actual letter: и
# Prediction: ж, Actual letter: и
# Prediction: л, Actual letter: п
# Prediction: н, Actual letter: п
# Prediction: к, Actual letter: с
# Prediction: с, Actual letter: е
# Prediction: ж, Actual letter: т
# Prediction: г, Actual letter: ё
# Prediction: х, Actual letter: ф
# Prediction: х, Actual letter: а
# Prediction: и, Actual letter: н
# Prediction: г, Actual letter: т
# Prediction: ё, Actual letter: й
# Prediction: ж, Actual letter: т
# Prediction: в, Actual letter: е
# Prediction: я, Actual letter: т
# Prediction: п, Actual letter: т
# Prediction: ф, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: ф, Actual letter: ж
# Prediction: х, Actual letter: е
# Prediction: к, Actual letter: н
# Prediction: х, Actual letter: а
# Prediction: г, Actual letter: в
# Prediction: е, Actual letter: ё
# Prediction: б, Actual letter: з
# Prediction: е, Actual letter: г
# Prediction: з, Actual letter: б
# Prediction: д, Actual letter: у
# Prediction: э, Actual letter: д
# Prediction: к, Actual letter: а
# Prediction: д, Actual letter: ф
# Prediction: с, Actual letter: ъ
# Prediction: х, Actual letter: е
# Prediction: с, Actual letter: п
# Prediction: м, Actual letter: л
# Prediction: л, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: а
# Prediction: д, Actual letter: з
# Prediction: ь, Actual letter: ъ
# Prediction: н, Actual letter: п
# Prediction: н, Actual letter: и
# Prediction: ж, Actual letter: н
# Prediction: в, Actual letter: г
# Prediction: л, Actual letter: г
# Prediction: л, Actual letter: я
# Prediction: ж, Actual letter: ш
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: у, Actual letter: ф
# Prediction: е, Actual letter: ё
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: т
# Prediction: ц, Actual letter: ш
# Prediction: д, Actual letter: г
# Prediction: н, Actual letter: и
# Prediction: ё, Actual letter: х
# Prediction: г, Actual letter: и
# Prediction: и, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: л, Actual letter: м
# Prediction: а, Actual letter: х
# Prediction: г, Actual letter: п
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: н
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: х
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: п
# Prediction: д, Actual letter: г
# Prediction: д, Actual letter: у
# Prediction: ь, Actual letter: в
# Prediction: л, Actual letter: ё
# Prediction: н, Actual letter: и
# Prediction: л, Actual letter: ь
# Prediction: д, Actual letter: з
# Prediction: з, Actual letter: ъ
# Prediction: м, Actual letter: п
# Prediction: щ, Actual letter: ц
# Prediction: с, Actual letter: о
# Prediction: в, Actual letter: ё
# Prediction: ь, Actual letter: и
# Prediction: м, Actual letter: щ
# Prediction: е, Actual letter: н
# Prediction: х, Actual letter: а
# Prediction: х, Actual letter: ф
# Prediction: ё, Actual letter: д
# Prediction: ё, Actual letter: в
# Prediction: х, Actual letter: п
# Prediction: к, Actual letter: п
# Prediction: ч, Actual letter: х
# Prediction: ы, Actual letter: ш
# Prediction: л, Actual letter: м
# Prediction: ж, Actual letter: т
# Prediction: ы, Actual letter: и
# Prediction: к, Actual letter: н
# Prediction: щ, Actual letter: ц
# Prediction: р, Actual letter: к
# Prediction: ж, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: ъ, Actual letter: г
# Prediction: щ, Actual letter: ю
# Prediction: к, Actual letter: н
# Prediction: а, Actual letter: к
# Prediction: я, Actual letter: ч
# Prediction: е, Actual letter: ч
# Prediction: з, Actual letter: д
# Prediction: и, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: о, Actual letter: а
# Prediction: н, Actual letter: я
# Prediction: к, Actual letter: н
# Prediction: д, Actual letter: з
# Prediction: с, Actual letter: х
# Prediction: п, Actual letter: к
# Prediction: х, Actual letter: ъ
# Prediction: д, Actual letter: у
# Prediction: н, Actual letter: к
# Prediction: г, Actual letter: ъ
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: к
# Prediction: х, Actual letter: я
# Prediction: к, Actual letter: х
# Prediction: ц, Actual letter: щ
# Prediction: ж, Actual letter: п
# Prediction: е, Actual letter: о
# Prediction: а, Actual letter: ы
# Prediction: б, Actual letter: д
# Prediction: п, Actual letter: а
# Prediction: х, Actual letter: ъ
# Prediction: г, Actual letter: п
# Prediction: д, Actual letter: г
# Prediction: в, Actual letter: ь
# Prediction: г, Actual letter: п
# Prediction: к, Actual letter: х
# Prediction: и, Actual letter: м
# Prediction: с, Actual letter: о
# Prediction: и, Actual letter: н
# Prediction: ы, Actual letter: ц
# Prediction: н, Actual letter: ж
# Prediction: я, Actual letter: ю
# Prediction: л, Actual letter: ь
# Prediction: л, Actual letter: м
# Prediction: б, Actual letter: ъ
# Prediction: б, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: д, Actual letter: ф
# Prediction: ц, Actual letter: щ
# Prediction: г, Actual letter: ч
# Prediction: ё, Actual letter: б
# Prediction: ь, Actual letter: ъ
# Prediction: к, Actual letter: о
# Prediction: ж, Actual letter: т
# Prediction: м, Actual letter: н
# Prediction: ь, Actual letter: ъ
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: з
# Prediction: ь, Actual letter: з
# Prediction: ж, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: а, Actual letter: ж
# Prediction: ь, Actual letter: л
# Prediction: д, Actual letter: ф
# Prediction: й, Actual letter: в
# Prediction: е, Actual letter: с
# Prediction: щ, Actual letter: ш
# Prediction: к, Actual letter: р
# Prediction: ж, Actual letter: к
# Prediction: м, Actual letter: ш
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: д, Actual letter: б
# Prediction: в, Actual letter: ь
# Prediction: с, Actual letter: т
# Prediction: ч, Actual letter: е
# Prediction: ж, Actual letter: ф
# Prediction: м, Actual letter: ж
# Prediction: ж, Actual letter: и
# Prediction: с, Actual letter: в
# Prediction: н, Actual letter: п
# Prediction: х, Actual letter: г
# Prediction: з, Actual letter: ё
# Prediction: ъ, Actual letter: в
# Prediction: у, Actual letter: з
# Prediction: о, Actual letter: ю
# Prediction: щ, Actual letter: ц
# Prediction: ж, Actual letter: х
# Prediction: с, Actual letter: е
# Prediction: н, Actual letter: т
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: ч
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: ш
# Prediction: е, Actual letter: ё
# Prediction: е, Actual letter: п
# Prediction: д, Actual letter: у
# Prediction: т, Actual letter: е
# Prediction: в, Actual letter: у
# Prediction: д, Actual letter: з
# Prediction: д, Actual letter: р
# Prediction: д, Actual letter: у
# Prediction: г, Actual letter: ч
# Prediction: э, Actual letter: ё
# Prediction: ч, Actual letter: ъ
# Prediction: ь, Actual letter: с
# Prediction: ь, Actual letter: в
# Prediction: д, Actual letter: з
# Prediction: к, Actual letter: и
# Prediction: ь, Actual letter: ц
# Prediction: и, Actual letter: н
# Prediction: ы, Actual letter: я
# Prediction: з, Actual letter: у
# Prediction: е, Actual letter: о
# Prediction: з, Actual letter: ф
# Prediction: х, Actual letter: и
# Prediction: й, Actual letter: в
# Prediction: г, Actual letter: ч
# Prediction: ч, Actual letter: ы
# Prediction: е, Actual letter: ю
# Prediction: е, Actual letter: л
# Prediction: а, Actual letter: х
# Prediction: р, Actual letter: п
# Prediction: х, Actual letter: ъ
# Prediction: з, Actual letter: у
# Prediction: г, Actual letter: й
# Prediction: с, Actual letter: е
# Prediction: у, Actual letter: д
# Prediction: е, Actual letter: ё
# Prediction: ы, Actual letter: ч
# Prediction: в, Actual letter: и
# Prediction: ч, Actual letter: г
# Prediction: я, Actual letter: э
# Prediction: л, Actual letter: м
# Prediction: г, Actual letter: ы
# Prediction: э, Actual letter: ь
# Prediction: я, Actual letter: а
# Prediction: ю, Actual letter: ш
# Prediction: э, Actual letter: о
# Prediction: ч, Actual letter: ъ
# Prediction: е, Actual letter: к
# Prediction: м, Actual letter: о
# Prediction: з, Actual letter: с
# Prediction: й, Actual letter: т
# Prediction: ч, Actual letter: г
# Prediction: и, Actual letter: м
# Prediction: ц, Actual letter: щ
# Prediction: х, Actual letter: ъ
# Prediction: ц, Actual letter: ш
# Prediction: л, Actual letter: х
# Prediction: щ, Actual letter: ш
# Prediction: з, Actual letter: д
# Prediction: к, Actual letter: н
# Prediction: г, Actual letter: х
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: н
# Prediction: е, Actual letter: с
# Prediction: д, Actual letter: у
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: ы
# Prediction: я, Actual letter: п
# Prediction: е, Actual letter: к
# Prediction: ф, Actual letter: т
# Prediction: с, Actual letter: ь
# Prediction: ч, Actual letter: ъ
# Prediction: с, Actual letter: п
# Prediction: ъ, Actual letter: ц
# Prediction: у, Actual letter: д
# Prediction: ё, Actual letter: г
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: к, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: ъ, Actual letter: ё
# Prediction: ф, Actual letter: х
# Prediction: ж, Actual letter: ш
# Prediction: ц, Actual letter: ч
# Prediction: л, Actual letter: о
# Prediction: ж, Actual letter: щ
# Prediction: х, Actual letter: ф
# Prediction: я, Actual letter: ь
# Prediction: е, Actual letter: ь
# Prediction: ы, Actual letter: и
# Prediction: ё, Actual letter: а
# Prediction: а, Actual letter: ю
# Prediction: ы, Actual letter: ш
# Prediction: е, Actual letter: с
# Prediction: к, Actual letter: ч
# Prediction: с, Actual letter: е
# Prediction: х, Actual letter: я
# Prediction: п, Actual letter: г
# Prediction: е, Actual letter: с
# Prediction: х, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: ж, Actual letter: л
# Prediction: л, Actual letter: я
# Prediction: ъ, Actual letter: д
# Prediction: ъ, Actual letter: ч
# Prediction: д, Actual letter: у
# Prediction: с, Actual letter: е
# Prediction: у, Actual letter: ф
# Prediction: ж, Actual letter: ч
# Prediction: я, Actual letter: а
# Prediction: х, Actual letter: ч
# Prediction: й, Actual letter: ч
# Prediction: х, Actual letter: ы
# Prediction: к, Actual letter: в
# Prediction: ч, Actual letter: г
# Prediction: л, Actual letter: и
# Prediction: ж, Actual letter: ш
# Prediction: и, Actual letter: ц
# Prediction: и, Actual letter: н
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: м
# Prediction: ё, Actual letter: в
# Prediction: р, Actual letter: к
# Prediction: в, Actual letter: е
# Prediction: й, Actual letter: т
# Prediction: ч, Actual letter: ъ
# Prediction: и, Actual letter: ц
# Prediction: в, Actual letter: е
# Prediction: ю, Actual letter: щ
# Prediction: у, Actual letter: ц
# Prediction: е, Actual letter: н
# Prediction: м, Actual letter: и
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: а
# Prediction: е, Actual letter: к
# Prediction: ь, Actual letter: в
# Prediction: ц, Actual letter: щ
# Prediction: л, Actual letter: и
# Prediction: с, Actual letter: ы
# Prediction: ж, Actual letter: к
# Prediction: д, Actual letter: ц
# Prediction: щ, Actual letter: ч
# Prediction: м, Actual letter: н
# Prediction: к, Actual letter: ы
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: п
# Prediction: ш, Actual letter: ы
# Prediction: т, Actual letter: ш
# Prediction: н, Actual letter: т
# Prediction: х, Actual letter: к
# Prediction: й, Actual letter: з
# Prediction: з, Actual letter: б
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ц
# Prediction: к, Actual letter: ю
# Prediction: и, Actual letter: а
# Prediction: л, Actual letter: и
# Prediction: и, Actual letter: н
# Prediction: н, Actual letter: ч
# Prediction: й, Actual letter: з
# Prediction: щ, Actual letter: ц
# Prediction: и, Actual letter: ц
# Prediction: я, Actual letter: е
# Prediction: г, Actual letter: ъ
# Prediction: ж, Actual letter: м
# Prediction: о, Actual letter: й
# Prediction: ы, Actual letter: п
# Prediction: ь, Actual letter: в
# Prediction: в, Actual letter: ь
# Prediction: з, Actual letter: у
# Prediction: в, Actual letter: ь
# Prediction: л, Actual letter: и
# Prediction: н, Actual letter: ы
# Prediction: э, Actual letter: ь
# Prediction: ц, Actual letter: щ
# Prediction: х, Actual letter: э
# Prediction: ю, Actual letter: т
# Prediction: я, Actual letter: м
# Prediction: ф, Actual letter: щ
# Prediction: ъ, Actual letter: г
# Prediction: щ, Actual letter: т
# Prediction: ж, Actual letter: ы
# Prediction: ч, Actual letter: п
# Prediction: к, Actual letter: а
# Prediction: ш, Actual letter: м
# Prediction: м, Actual letter: ж
# Prediction: з, Actual letter: б
# Prediction: ж, Actual letter: н
# Prediction: ж, Actual letter: х
# Prediction: д, Actual letter: з
# Prediction: и, Actual letter: ц
# Prediction: ф, Actual letter: с
# Prediction: б, Actual letter: ф
# Prediction: н, Actual letter: и
# Prediction: щ, Actual letter: ш
# Prediction: ж, Actual letter: т
# Prediction: в, Actual letter: е
# Prediction: с, Actual letter: е
# Prediction: ш, Actual letter: т
# Prediction: г, Actual letter: х
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: э
# Prediction: к, Actual letter: п
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: ш
# Prediction: я, Actual letter: й
# Prediction: з, Actual letter: х
# Prediction: ч, Actual letter: ц
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: ч, Actual letter: я
# Prediction: г, Actual letter: ъ
# Prediction: л, Actual letter: к
# Prediction: в, Actual letter: ь
# Prediction: я, Actual letter: а
# Prediction: е, Actual letter: в
# Prediction: х, Actual letter: н
# Prediction: ч, Actual letter: г
# Prediction: и, Actual letter: а
# Prediction: е, Actual letter: ё
# Prediction: щ, Actual letter: ц
# Prediction: д, Actual letter: у
# Prediction: ё, Actual letter: д
# Prediction: ю, Actual letter: а
# Prediction: ё, Actual letter: б
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: м
# Prediction: п, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: м, Actual letter: и
# Prediction: г, Actual letter: я
# Prediction: т, Actual letter: ю
# Prediction: д, Actual letter: у
# Prediction: о, Actual letter: й
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: г
# Prediction: ф, Actual letter: щ
# Prediction: ф, Actual letter: ц
# Prediction: м, Actual letter: ш
# Prediction: к, Actual letter: н
# Prediction: ч, Actual letter: ъ
# Prediction: г, Actual letter: п
# Prediction: ц, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: а, Actual letter: г
# Prediction: б, Actual letter: к
# Prediction: д, Actual letter: о
# Prediction: л, Actual letter: в
# Prediction: в, Actual letter: х
# Prediction: д, Actual letter: з
# Prediction: к, Actual letter: е
# Prediction: в, Actual letter: г
# Prediction: д, Actual letter: л
# Prediction: ъ, Actual letter: г
# Prediction: ч, Actual letter: я
# Prediction: д, Actual letter: ф
# Prediction: ч, Actual letter: ц
# Prediction: с, Actual letter: ф
# Prediction: й, Actual letter: б
# Prediction: и, Actual letter: ч
# Prediction: ч, Actual letter: г
# Prediction: с, Actual letter: е
# Prediction: о, Actual letter: з
# Prediction: л, Actual letter: и
# Prediction: е, Actual letter: ё
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: я, Actual letter: м
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ы
# Prediction: и, Actual letter: н
# Prediction: з, Actual letter: ж
# Prediction: к, Actual letter: ю
# Prediction: ъ, Actual letter: з
# Prediction: м, Actual letter: н
# Prediction: х, Actual letter: г
# Prediction: ё, Actual letter: б
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: й
# Prediction: е, Actual letter: в
# Prediction: м, Actual letter: х
# Prediction: б, Actual letter: ё
# Prediction: ы, Actual letter: ч
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: ы
# Prediction: и, Actual letter: а
# Prediction: ж, Actual letter: ч
# Prediction: ш, Actual letter: ж
# Prediction: г, Actual letter: ч
# Prediction: п, Actual letter: л
# Prediction: ж, Actual letter: л
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: а
# Prediction: е, Actual letter: х
# Prediction: ч, Actual letter: ъ
# Prediction: ы, Actual letter: к
# Prediction: х, Actual letter: ю
# Prediction: х, Actual letter: а
# Prediction: н, Actual letter: и
# Prediction: с, Actual letter: е
# Prediction: д, Actual letter: у
# Prediction: ъ, Actual letter: ё
# Prediction: т, Actual letter: ы
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: х, Actual letter: ф
# Prediction: ф, Actual letter: ю
# Prediction: д, Actual letter: ъ
# Accuracy: 0.9295278365045807, My Accuracy: 0.9295278365045807

# %% [markdown]
# <h3>После создания сверточной нейронной сети и настройки гиперпараметров удалось получить модель, корректно классифицирующую русские буквы с вероятностью 94%(на тестовой выборке)</h3>

# %% [markdown]
# <h1>4. Сверточная нейронная сеть на расширенных данных.</h1>

# %% [markdown]
# <h3>Я не очень понимаю, что требуется сделать в этом пункте, так как если я обучу нейросеть на всех данных, то на чем мне ее тестировать, поэтому я сейчас сделаю скрипт и буду сам рисовать </h3>

# %%
images_folder_path = 'additional_data'

X_additional, y_additional = [], []

for root, dirs, files in os.walk(images_folder_path):
    for file in files:
            file_path = os.path.join(root, file)
            
            with Image.open(file_path) as img:
                img = img.convert('L')  # Convert to grayscale
                #img = img.resize((32, 32))  # Resize the image
                
                img_flattened = np.array(img).flatten()
                
                # Print the directory name
                directory_name = os.path.basename(root)
                
                X_additional.append(img_flattened)
                y_additional.append(letter_to_label[directory_name])

# %%
y_additional = np.array(y_additional)

X_additional = np.array(X_additional) 

X_additional_reshaped = X_additional.reshape((-1, 32, 32, 1))
print(len(X_additional_reshaped))
# complex_CNN.compile(optimizer=Adam(learning_rate=0.001),
#                 loss='sparse_categorical_crossentropy',
#                 metrics=['accuracy'])

# complex_CNN_history = complex_CNN.fit(X_additional_reshaped, y_additional, epochs=10, batch_size=64, validation_split=0.1)
test_model(complex_CNN, X_additional_reshaped, X, y_additional, y, NN=True, only_train=True)
#test_model(complex_CNN, X_additional_reshaped, X, y_additional, y, NN=True, only_train=True)

print(X_train_reshaped[0])
print(X_additional_reshaped[0])
# Out:
# 1651
# Training data test
# 52/52 [==============================] - 1s 10ms/step
# [23 29 28 ... 23 28 21]
# Prediction: х, Actual letter: ё
# Prediction: ы, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: х, Actual letter: ё
# Prediction: х, Actual letter: ё
# Prediction: в, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: в, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ю, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: х, Actual letter: ё
# Prediction: х, Actual letter: ё
# Prediction: ф, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: щ, Actual letter: а
# Prediction: х, Actual letter: а
# Prediction: с, Actual letter: а
# Prediction: т, Actual letter: а
# Prediction: х, Actual letter: а
# Prediction: ы, Actual letter: а
# Prediction: ц, Actual letter: а
# Prediction: щ, Actual letter: а
# Prediction: х, Actual letter: а
# Prediction: ъ, Actual letter: б
# Prediction: в, Actual letter: б
# Prediction: э, Actual letter: б
# Prediction: ь, Actual letter: б
# Prediction: ю, Actual letter: б
# Prediction: ъ, Actual letter: б
# Prediction: ь, Actual letter: б
# Prediction: ъ, Actual letter: б
# Prediction: в, Actual letter: б
# Prediction: ъ, Actual letter: б
# Prediction: э, Actual letter: б
# Prediction: й, Actual letter: в
# Prediction: у, Actual letter: в
# Prediction: й, Actual letter: в
# Prediction: й, Actual letter: в
# Prediction: ь, Actual letter: в
# Prediction: а, Actual letter: г
# Prediction: ф, Actual letter: г
# Prediction: х, Actual letter: г
# Prediction: а, Actual letter: г
# Prediction: у, Actual letter: г
# Prediction: а, Actual letter: г
# Prediction: а, Actual letter: г
# Prediction: х, Actual letter: г
# Prediction: ъ, Actual letter: г
# Prediction: ъ, Actual letter: г
# Prediction: ф, Actual letter: г
# Prediction: ъ, Actual letter: г
# Prediction: у, Actual letter: г
# Prediction: ъ, Actual letter: г
# Prediction: а, Actual letter: г
# Prediction: х, Actual letter: г
# Prediction: в, Actual letter: г
# Prediction: а, Actual letter: г
# Prediction: х, Actual letter: г
# Prediction: ъ, Actual letter: г
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: я, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: я, Actual letter: д
# Prediction: ъ, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ъ, Actual letter: д
# Prediction: ъ, Actual letter: д
# Prediction: ъ, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ъ, Actual letter: д
# Prediction: ф, Actual letter: д
# Prediction: ё, Actual letter: е
# Prediction: ё, Actual letter: е
# Prediction: ё, Actual letter: е
# Prediction: в, Actual letter: е
# Prediction: с, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: о, Actual letter: е
# Prediction: о, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: ю, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: й, Actual letter: е
# Prediction: й, Actual letter: е
# Prediction: о, Actual letter: е
# Prediction: а, Actual letter: е
# Prediction: й, Actual letter: е
# Prediction: ъ, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: с, Actual letter: е
# Prediction: а, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: х, Actual letter: е
# Prediction: щ, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: у, Actual letter: ж
# Prediction: у, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: ж
# Prediction: в, Actual letter: ж
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: у, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: э, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ф, Actual letter: з
# Prediction: у, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: ъ, Actual letter: з
# Prediction: х, Actual letter: з
# Prediction: ш, Actual letter: и
# Prediction: ш, Actual letter: и
# Prediction: у, Actual letter: и
# Prediction: а, Actual letter: и
# Prediction: ы, Actual letter: и
# Prediction: ш, Actual letter: и
# Prediction: ц, Actual letter: и
# Prediction: ш, Actual letter: и
# Prediction: т, Actual letter: и
# Prediction: щ, Actual letter: и
# Prediction: ц, Actual letter: и
# Prediction: ы, Actual letter: и
# Prediction: т, Actual letter: и
# Prediction: а, Actual letter: и
# Prediction: щ, Actual letter: и
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: ы, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: ы, Actual letter: й
# Prediction: ы, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: с, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: ъ, Actual letter: й
# Prediction: ъ, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: ъ, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: а, Actual letter: й
# Prediction: х, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: ы, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ф, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: в, Actual letter: к
# Prediction: а, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: ъ, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: х, Actual letter: к
# Prediction: щ, Actual letter: к
# Prediction: в, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: т, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: ю, Actual letter: к
# Prediction: т, Actual letter: к
# Prediction: а, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: ы, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: щ, Actual letter: л
# Prediction: ы, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: в, Actual letter: л
# Prediction: в, Actual letter: л
# Prediction: ё, Actual letter: л
# Prediction: в, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: з, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: з, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: и, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: у, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: ы, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: х, Actual letter: л
# Prediction: а, Actual letter: л
# Prediction: ы, Actual letter: м
# Prediction: ж, Actual letter: м
# Prediction: к, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: в, Actual letter: м
# Prediction: а, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ж, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ы, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ж, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: х, Actual letter: м
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ж, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: к, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: щ, Actual letter: н
# Prediction: ш, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: в, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: й, Actual letter: н
# Prediction: в, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: х, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: щ, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: х, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: й, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ю, Actual letter: н
# Prediction: х, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: в, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: ш, Actual letter: н
# Prediction: щ, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: ф, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: ж, Actual letter: н
# Prediction: в, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: ы, Actual letter: н
# Prediction: а, Actual letter: н
# Prediction: ъ, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ф, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: в, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ю, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: у, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ю, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ю, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ю, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: в, Actual letter: о
# Prediction: к, Actual letter: о
# Prediction: с, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: э, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: ь, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: х, Actual letter: о
# Prediction: щ, Actual letter: о
# Prediction: ъ, Actual letter: о
# Prediction: в, Actual letter: п
# Prediction: ы, Actual letter: п
# Prediction: ы, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: ю, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: х, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: ъ, Actual letter: п
# Prediction: у, Actual letter: п
# Prediction: ъ, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: ы, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: ы, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: щ, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: х, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: н, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: щ, Actual letter: п
# Prediction: ю, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: т, Actual letter: п
# Prediction: а, Actual letter: п
# Prediction: ф, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: ж, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: а, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: ы, Actual letter: р
# Prediction: а, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: п, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: с, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: п, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: ф, Actual letter: р
# Prediction: т, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: х, Actual letter: р
# Prediction: у, Actual letter: р
# Prediction: е, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: й, Actual letter: с
# Prediction: ё, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: в, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: в, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: ю, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: в, Actual letter: с
# Prediction: в, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: ё, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: ё, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: ё, Actual letter: с
# Prediction: ё, Actual letter: с
# Prediction: к, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: х, Actual letter: с
# Prediction: ф, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ы, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ю, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: ы, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: к, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ы, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: ъ, Actual letter: т
# Prediction: у, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: н, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: в, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: ы, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: щ, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: ф, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: й, Actual letter: у
# Prediction: ц, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: и, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: в, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: з, Actual letter: у
# Prediction: ф, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ф, Actual letter: у
# Prediction: а, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ф, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: а, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ъ, Actual letter: у
# Prediction: ф, Actual letter: у
# Prediction: ь, Actual letter: у
# Prediction: ь, Actual letter: у
# Prediction: в, Actual letter: у
# Prediction: ы, Actual letter: у
# Prediction: щ, Actual letter: у
# Prediction: л, Actual letter: у
# Prediction: х, Actual letter: ф
# Prediction: щ, Actual letter: ф
# Prediction: щ, Actual letter: ф
# Prediction: х, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: х, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: х, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ъ, Actual letter: ф
# Prediction: ю, Actual letter: ф
# Prediction: к, Actual letter: х
# Prediction: н, Actual letter: х
# Prediction: ф, Actual letter: х
# Prediction: н, Actual letter: х
# Prediction: ч, Actual letter: х
# Prediction: ъ, Actual letter: х
# Prediction: я, Actual letter: х
# Prediction: е, Actual letter: х
# Prediction: у, Actual letter: х
# Prediction: ы, Actual letter: х
# Prediction: ж, Actual letter: х
# Prediction: к, Actual letter: х
# Prediction: у, Actual letter: х
# Prediction: у, Actual letter: х
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: ъ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: а, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: ш, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: ю, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: л, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: ю, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: а, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: а, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: к, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: а, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: у, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: ф, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: к, Actual letter: ч
# Prediction: ф, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: щ, Actual letter: ч
# Prediction: в, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: к, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: в, Actual letter: ч
# Prediction: а, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: у, Actual letter: ч
# Prediction: в, Actual letter: ч
# Prediction: ж, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: щ, Actual letter: ч
# Prediction: ф, Actual letter: ч
# Prediction: ю, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: ю, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: й, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: к, Actual letter: ч
# Prediction: ы, Actual letter: ч
# Prediction: у, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: щ, Actual letter: ч
# Prediction: к, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: й, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: н, Actual letter: ч
# Prediction: т, Actual letter: ч
# Prediction: щ, Actual letter: ч
# Prediction: у, Actual letter: ч
# Prediction: х, Actual letter: ч
# Prediction: ь, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: щ, Actual letter: ч
# Prediction: ъ, Actual letter: ч
# Prediction: й, Actual letter: ч
# Prediction: а, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: а, Actual letter: ш
# Prediction: й, Actual letter: ш
# Prediction: ы, Actual letter: ш
# Prediction: ы, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: ш
# Prediction: ы, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: ю, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: х, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: х, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: х, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: щ, Actual letter: ш
# Prediction: ю, Actual letter: щ
# Prediction: ю, Actual letter: щ
# Prediction: т, Actual letter: щ
# Prediction: ю, Actual letter: щ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: з, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: ж, Actual letter: ъ
# Prediction: а, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: х, Actual letter: ъ
# Prediction: щ, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: ж, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: ш, Actual letter: ы
# Prediction: ш, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: к, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: в, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: л, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: й, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: а, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: ш, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: а, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: и, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: в, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: ж, Actual letter: ы
# Prediction: в, Actual letter: ы
# Prediction: щ, Actual letter: ы
# Prediction: ю, Actual letter: ы
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ю, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: н, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: а, Actual letter: ь
# Prediction: ы, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ю, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: а, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ы, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: у, Actual letter: ь
# Prediction: к, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ы, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: ы, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: х, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: ц, Actual letter: ь
# Prediction: щ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ъ, Actual letter: ь
# Prediction: в, Actual letter: ь
# Prediction: ж, Actual letter: э
# Prediction: в, Actual letter: э
# Prediction: ф, Actual letter: э
# Prediction: з, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: з, Actual letter: э
# Prediction: у, Actual letter: э
# Prediction: у, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: з, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: х, Actual letter: э
# Prediction: ф, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: б, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: у, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: в, Actual letter: э
# Prediction: ф, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: ъ, Actual letter: э
# Prediction: у, Actual letter: э
# Prediction: з, Actual letter: э
# Prediction: т, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: ж, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: ы, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: ы, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: ы, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ю
# Prediction: т, Actual letter: ю
# Prediction: к, Actual letter: ю
# Prediction: ж, Actual letter: я
# Prediction: з, Actual letter: я
# Prediction: в, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: у, Actual letter: я
# Prediction: з, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: в, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: э, Actual letter: я
# Prediction: у, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ы, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: з, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: в, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: в, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: б, Actual letter: я
# Prediction: ы, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: у, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ы, Actual letter: я
# Prediction: в, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: щ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: б, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: ы, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: у, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: ж, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: з, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: у, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: х, Actual letter: я
# Prediction: ъ, Actual letter: я
# Prediction: у, Actual letter: я
# Accuracy: 0.28225317989097515, My Accuracy: 0.28225317989097515
# [[[0.4627451 ]
#   [0.47058824]
#   [0.47058824]
#   ...
#   [0.4627451 ]
#   [0.4627451 ]
#   [0.47058824]]
#
#  [[0.46666667]
#   [0.47058824]
#   [0.47058824]
#   ...
#   [0.46666667]
#   [0.4627451 ]
#   [0.46666667]]
#
#  [[0.4627451 ]
#   [0.47058824]
#   [0.46666667]
#   ...
#   [0.47058824]
#   [0.46666667]
#   [0.47058824]]
#
#  ...
#
#  [[0.50980392]
#   [0.51372549]
#   [0.50980392]
#   ...
#   [0.50980392]
#   [0.50588235]
#   [0.50980392]]
#
#  [[0.50588235]
#   [0.50980392]
#   [0.51372549]
#   ...
#   [0.50980392]
#   [0.51372549]
#   [0.50980392]]
#
#  [[0.51372549]
#   [0.50980392]
#   [0.50980392]
#   ...
#   [0.50980392]
#   [0.51372549]
#   [0.50980392]]]
# [[[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]
#
#  [[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]
#
#  [[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]
#
#  ...
#
#  [[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]
#
#  [[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]
#
#  [[255]
#   [255]
#   [255]
#   ...
#   [255]
#   [255]
#   [255]]]

# %%
test_model(complex_CNN, X_train_reshaped, X, y_train, y, NN=True, only_train=True)
# Out:
# Training data test
# 400/400 [==============================] - 3s 8ms/step
# [25 16 10 ...  5  6 32]
# Prediction: и, Actual letter: н
# Prediction: в, Actual letter: ь
# Prediction: л, Actual letter: п
# Prediction: ж, Actual letter: ш
# Prediction: ж, Actual letter: к
# Prediction: н, Actual letter: к
# Prediction: г, Actual letter: е
# Prediction: ё, Actual letter: б
# Prediction: н, Actual letter: ж
# Prediction: х, Actual letter: я
# Prediction: е, Actual letter: ь
# Prediction: ы, Actual letter: и
# Prediction: щ, Actual letter: ш
# Prediction: п, Actual letter: а
# Prediction: е, Actual letter: с
# Prediction: ч, Actual letter: г
# Prediction: ы, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: н, Actual letter: ы
# Prediction: д, Actual letter: у
# Prediction: е, Actual letter: ё
# Prediction: к, Actual letter: н
# Prediction: э, Actual letter: ф
# Prediction: г, Actual letter: ю
# Prediction: щ, Actual letter: а
# Prediction: з, Actual letter: ъ
# Prediction: з, Actual letter: ф
# Prediction: э, Actual letter: я
# Prediction: д, Actual letter: у
# Prediction: ж, Actual letter: и
# Prediction: ы, Actual letter: и
# Prediction: ж, Actual letter: и
# Prediction: н, Actual letter: и
# Prediction: м, Actual letter: ш
# Prediction: у, Actual letter: ч
# Prediction: з, Actual letter: э
# Prediction: ъ, Actual letter: ч
# Prediction: о, Actual letter: п
# Prediction: к, Actual letter: ю
# Prediction: г, Actual letter: х
# Prediction: я, Actual letter: н
# Prediction: ь, Actual letter: в
# Prediction: ж, Actual letter: и
# Prediction: ь, Actual letter: с
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: ж
# Prediction: о, Actual letter: ф
# Prediction: ы, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: о
# Prediction: л, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: а
# Prediction: я, Actual letter: в
# Prediction: к, Actual letter: н
# Prediction: я, Actual letter: а
# Prediction: ы, Actual letter: ю
# Prediction: а, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: а
# Prediction: э, Actual letter: я
# Prediction: в, Actual letter: ё
# Prediction: б, Actual letter: ъ
# Prediction: ч, Actual letter: ъ
# Prediction: ж, Actual letter: т
# Prediction: з, Actual letter: ч
# Prediction: д, Actual letter: у
# Prediction: в, Actual letter: ъ
# Prediction: ж, Actual letter: х
# Prediction: х, Actual letter: а
# Prediction: д, Actual letter: в
# Prediction: с, Actual letter: й
# Prediction: в, Actual letter: ь
# Prediction: ж, Actual letter: ы
# Prediction: ф, Actual letter: х
# Prediction: з, Actual letter: ч
# Prediction: ф, Actual letter: щ
# Prediction: х, Actual letter: а
# Prediction: д, Actual letter: ь
# Prediction: й, Actual letter: в
# Prediction: ь, Actual letter: ъ
# Prediction: л, Actual letter: р
# Prediction: и, Actual letter: п
# Prediction: ж, Actual letter: н
# Prediction: ъ, Actual letter: ц
# Prediction: ж, Actual letter: и
# Prediction: л, Actual letter: а
# Prediction: я, Actual letter: д
# Prediction: ж, Actual letter: ш
# Prediction: э, Actual letter: ч
# Prediction: в, Actual letter: к
# Prediction: з, Actual letter: о
# Prediction: д, Actual letter: ф
# Prediction: к, Actual letter: н
# Prediction: д, Actual letter: о
# Prediction: и, Actual letter: й
# Prediction: щ, Actual letter: ц
# Prediction: м, Actual letter: ю
# Prediction: д, Actual letter: ф
# Prediction: г, Actual letter: н
# Prediction: в, Actual letter: к
# Prediction: т, Actual letter: п
# Prediction: ы, Actual letter: к
# Prediction: н, Actual letter: и
# Prediction: о, Actual letter: а
# Prediction: л, Actual letter: я
# Prediction: и, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: х, Actual letter: и
# Prediction: я, Actual letter: а
# Prediction: ж, Actual letter: н
# Prediction: з, Actual letter: ъ
# Prediction: е, Actual letter: о
# Prediction: ч, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: з, Actual letter: т
# Prediction: а, Actual letter: ш
# Prediction: й, Actual letter: ъ
# Prediction: в, Actual letter: ь
# Prediction: й, Actual letter: о
# Prediction: м, Actual letter: и
# Prediction: я, Actual letter: л
# Prediction: ж, Actual letter: ы
# Prediction: н, Actual letter: к
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: д, Actual letter: ф
# Prediction: к, Actual letter: и
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: я, Actual letter: м
# Prediction: и, Actual letter: н
# Prediction: е, Actual letter: ё
# Prediction: щ, Actual letter: ш
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: ф
# Prediction: г, Actual letter: т
# Prediction: д, Actual letter: у
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: р
# Prediction: д, Actual letter: ъ
# Prediction: у, Actual letter: р
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: м
# Prediction: ф, Actual letter: ы
# Prediction: ч, Actual letter: г
# Prediction: з, Actual letter: о
# Prediction: с, Actual letter: а
# Prediction: д, Actual letter: ф
# Prediction: ы, Actual letter: а
# Prediction: я, Actual letter: ю
# Prediction: к, Actual letter: п
# Prediction: з, Actual letter: д
# Prediction: д, Actual letter: о
# Prediction: л, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: к
# Prediction: ь, Actual letter: ы
# Prediction: д, Actual letter: о
# Prediction: м, Actual letter: ш
# Prediction: к, Actual letter: х
# Prediction: ё, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: я, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: п, Actual letter: к
# Prediction: т, Actual letter: п
# Prediction: ж, Actual letter: п
# Prediction: и, Actual letter: н
# Prediction: с, Actual letter: а
# Prediction: к, Actual letter: е
# Prediction: к, Actual letter: п
# Prediction: х, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: з
# Prediction: э, Actual letter: ы
# Prediction: щ, Actual letter: ш
# Prediction: ь, Actual letter: а
# Prediction: д, Actual letter: з
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: х
# Prediction: з, Actual letter: д
# Prediction: ж, Actual letter: н
# Prediction: л, Actual letter: м
# Prediction: ф, Actual letter: т
# Prediction: л, Actual letter: м
# Prediction: л, Actual letter: м
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: н
# Prediction: с, Actual letter: е
# Prediction: ф, Actual letter: р
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: с
# Prediction: ц, Actual letter: ш
# Prediction: щ, Actual letter: т
# Prediction: у, Actual letter: з
# Prediction: н, Actual letter: и
# Prediction: э, Actual letter: ч
# Prediction: ж, Actual letter: ы
# Prediction: д, Actual letter: ъ
# Prediction: з, Actual letter: ф
# Prediction: х, Actual letter: г
# Prediction: ж, Actual letter: п
# Prediction: з, Actual letter: д
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: н
# Prediction: я, Actual letter: ч
# Prediction: я, Actual letter: м
# Prediction: ж, Actual letter: т
# Prediction: о, Actual letter: а
# Prediction: е, Actual letter: с
# Prediction: л, Actual letter: а
# Prediction: к, Actual letter: п
# Prediction: е, Actual letter: х
# Prediction: з, Actual letter: ц
# Prediction: ж, Actual letter: н
# Prediction: ь, Actual letter: а
# Prediction: е, Actual letter: н
# Prediction: с, Actual letter: о
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: ё
# Prediction: ь, Actual letter: в
# Prediction: у, Actual letter: д
# Prediction: е, Actual letter: с
# Prediction: ъ, Actual letter: ш
# Prediction: к, Actual letter: ь
# Prediction: ц, Actual letter: п
# Prediction: ы, Actual letter: н
# Prediction: ь, Actual letter: в
# Prediction: ф, Actual letter: р
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: ю
# Prediction: в, Actual letter: п
# Prediction: э, Actual letter: я
# Prediction: ф, Actual letter: ю
# Prediction: х, Actual letter: а
# Prediction: я, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: ъ, Actual letter: в
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: г
# Prediction: ф, Actual letter: к
# Prediction: ь, Actual letter: а
# Prediction: м, Actual letter: ж
# Prediction: ф, Actual letter: ж
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: л
# Prediction: м, Actual letter: ш
# Prediction: ш, Actual letter: т
# Prediction: к, Actual letter: и
# Prediction: м, Actual letter: ш
# Prediction: л, Actual letter: м
# Prediction: л, Actual letter: и
# Prediction: е, Actual letter: г
# Prediction: щ, Actual letter: ш
# Prediction: п, Actual letter: а
# Prediction: с, Actual letter: е
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: ф
# Prediction: х, Actual letter: а
# Prediction: п, Actual letter: т
# Prediction: ж, Actual letter: щ
# Prediction: ъ, Actual letter: ч
# Prediction: а, Actual letter: о
# Prediction: в, Actual letter: ч
# Prediction: ы, Actual letter: п
# Prediction: в, Actual letter: а
# Prediction: е, Actual letter: ь
# Prediction: о, Actual letter: с
# Prediction: е, Actual letter: с
# Prediction: ц, Actual letter: ш
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ш
# Prediction: ы, Actual letter: о
# Prediction: ж, Actual letter: т
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: и
# Prediction: я, Actual letter: а
# Prediction: г, Actual letter: ч
# Prediction: я, Actual letter: н
# Prediction: л, Actual letter: м
# Prediction: г, Actual letter: п
# Prediction: м, Actual letter: и
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: а
# Prediction: б, Actual letter: й
# Prediction: ь, Actual letter: ч
# Prediction: ш, Actual letter: а
# Prediction: г, Actual letter: а
# Prediction: у, Actual letter: ё
# Prediction: щ, Actual letter: ш
# Prediction: у, Actual letter: щ
# Prediction: к, Actual letter: н
# Prediction: щ, Actual letter: ш
# Prediction: я, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: п, Actual letter: т
# Prediction: р, Actual letter: к
# Prediction: в, Actual letter: г
# Prediction: з, Actual letter: а
# Prediction: с, Actual letter: п
# Prediction: е, Actual letter: а
# Prediction: х, Actual letter: и
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: п
# Prediction: у, Actual letter: ф
# Prediction: х, Actual letter: я
# Prediction: д, Actual letter: ь
# Prediction: и, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: к, Actual letter: п
# Prediction: х, Actual letter: и
# Prediction: д, Actual letter: у
# Prediction: я, Actual letter: а
# Prediction: ч, Actual letter: ъ
# Prediction: ч, Actual letter: т
# Prediction: щ, Actual letter: ш
# Prediction: ж, Actual letter: н
# Prediction: к, Actual letter: п
# Prediction: ж, Actual letter: н
# Prediction: ч, Actual letter: с
# Prediction: к, Actual letter: п
# Prediction: к, Actual letter: ю
# Prediction: д, Actual letter: б
# Prediction: в, Actual letter: ч
# Prediction: и, Actual letter: г
# Prediction: я, Actual letter: и
# Prediction: а, Actual letter: т
# Prediction: е, Actual letter: с
# Prediction: д, Actual letter: г
# Prediction: х, Actual letter: ж
# Prediction: д, Actual letter: з
# Prediction: с, Actual letter: а
# Prediction: е, Actual letter: п
# Prediction: в, Actual letter: й
# Prediction: н, Actual letter: ы
# Prediction: к, Actual letter: п
# Prediction: с, Actual letter: з
# Prediction: м, Actual letter: т
# Prediction: г, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: ц
# Prediction: щ, Actual letter: ш
# Prediction: е, Actual letter: к
# Prediction: е, Actual letter: к
# Prediction: л, Actual letter: й
# Prediction: д, Actual letter: в
# Prediction: ж, Actual letter: м
# Prediction: з, Actual letter: у
# Prediction: ж, Actual letter: м
# Prediction: д, Actual letter: у
# Prediction: д, Actual letter: р
# Prediction: а, Actual letter: ш
# Prediction: г, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: г, Actual letter: ъ
# Prediction: е, Actual letter: г
# Prediction: ч, Actual letter: ц
# Prediction: у, Actual letter: ъ
# Prediction: х, Actual letter: у
# Prediction: ш, Actual letter: щ
# Prediction: э, Actual letter: я
# Prediction: л, Actual letter: м
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: о
# Prediction: п, Actual letter: т
# Prediction: к, Actual letter: н
# Prediction: ж, Actual letter: н
# Prediction: л, Actual letter: т
# Prediction: ж, Actual letter: и
# Prediction: д, Actual letter: ф
# Prediction: э, Actual letter: ь
# Prediction: е, Actual letter: ю
# Prediction: д, Actual letter: з
# Prediction: и, Actual letter: ш
# Prediction: г, Actual letter: ш
# Prediction: п, Actual letter: к
# Prediction: я, Actual letter: п
# Prediction: п, Actual letter: г
# Prediction: л, Actual letter: и
# Prediction: в, Actual letter: ё
# Prediction: щ, Actual letter: ю
# Prediction: м, Actual letter: ш
# Prediction: м, Actual letter: ш
# Prediction: я, Actual letter: и
# Prediction: ж, Actual letter: и
# Prediction: л, Actual letter: п
# Prediction: н, Actual letter: п
# Prediction: к, Actual letter: с
# Prediction: с, Actual letter: е
# Prediction: ж, Actual letter: т
# Prediction: г, Actual letter: ё
# Prediction: х, Actual letter: ф
# Prediction: х, Actual letter: а
# Prediction: и, Actual letter: н
# Prediction: г, Actual letter: т
# Prediction: ё, Actual letter: й
# Prediction: ж, Actual letter: т
# Prediction: в, Actual letter: е
# Prediction: я, Actual letter: т
# Prediction: п, Actual letter: т
# Prediction: ф, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: ф, Actual letter: ж
# Prediction: х, Actual letter: е
# Prediction: к, Actual letter: н
# Prediction: х, Actual letter: а
# Prediction: г, Actual letter: в
# Prediction: е, Actual letter: ё
# Prediction: б, Actual letter: з
# Prediction: е, Actual letter: г
# Prediction: з, Actual letter: б
# Prediction: д, Actual letter: у
# Prediction: э, Actual letter: д
# Prediction: к, Actual letter: а
# Prediction: д, Actual letter: ф
# Prediction: с, Actual letter: ъ
# Prediction: х, Actual letter: е
# Prediction: с, Actual letter: п
# Prediction: м, Actual letter: л
# Prediction: л, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: я, Actual letter: а
# Prediction: д, Actual letter: з
# Prediction: ь, Actual letter: ъ
# Prediction: н, Actual letter: п
# Prediction: н, Actual letter: и
# Prediction: ж, Actual letter: н
# Prediction: в, Actual letter: г
# Prediction: л, Actual letter: г
# Prediction: л, Actual letter: я
# Prediction: ж, Actual letter: ш
# Prediction: ж, Actual letter: т
# Prediction: ж, Actual letter: т
# Prediction: у, Actual letter: ф
# Prediction: е, Actual letter: ё
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: т
# Prediction: ц, Actual letter: ш
# Prediction: д, Actual letter: г
# Prediction: н, Actual letter: и
# Prediction: ё, Actual letter: х
# Prediction: г, Actual letter: и
# Prediction: и, Actual letter: а
# Prediction: ж, Actual letter: т
# Prediction: л, Actual letter: м
# Prediction: а, Actual letter: х
# Prediction: г, Actual letter: п
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: н
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: х
# Prediction: ж, Actual letter: т
# Prediction: е, Actual letter: п
# Prediction: д, Actual letter: г
# Prediction: д, Actual letter: у
# Prediction: ь, Actual letter: в
# Prediction: л, Actual letter: ё
# Prediction: н, Actual letter: и
# Prediction: л, Actual letter: ь
# Prediction: д, Actual letter: з
# Prediction: з, Actual letter: ъ
# Prediction: м, Actual letter: п
# Prediction: щ, Actual letter: ц
# Prediction: с, Actual letter: о
# Prediction: в, Actual letter: ё
# Prediction: ь, Actual letter: и
# Prediction: м, Actual letter: щ
# Prediction: е, Actual letter: н
# Prediction: х, Actual letter: а
# Prediction: х, Actual letter: ф
# Prediction: ё, Actual letter: д
# Prediction: ё, Actual letter: в
# Prediction: х, Actual letter: п
# Prediction: к, Actual letter: п
# Prediction: ч, Actual letter: х
# Prediction: ы, Actual letter: ш
# Prediction: л, Actual letter: м
# Prediction: ж, Actual letter: т
# Prediction: ы, Actual letter: и
# Prediction: к, Actual letter: н
# Prediction: щ, Actual letter: ц
# Prediction: р, Actual letter: к
# Prediction: ж, Actual letter: а
# Prediction: з, Actual letter: у
# Prediction: ъ, Actual letter: г
# Prediction: щ, Actual letter: ю
# Prediction: к, Actual letter: н
# Prediction: а, Actual letter: к
# Prediction: я, Actual letter: ч
# Prediction: е, Actual letter: ч
# Prediction: з, Actual letter: д
# Prediction: и, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: о, Actual letter: а
# Prediction: н, Actual letter: я
# Prediction: к, Actual letter: н
# Prediction: д, Actual letter: з
# Prediction: с, Actual letter: х
# Prediction: п, Actual letter: к
# Prediction: х, Actual letter: ъ
# Prediction: д, Actual letter: у
# Prediction: н, Actual letter: к
# Prediction: г, Actual letter: ъ
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: к
# Prediction: х, Actual letter: я
# Prediction: к, Actual letter: х
# Prediction: ц, Actual letter: щ
# Prediction: ж, Actual letter: п
# Prediction: е, Actual letter: о
# Prediction: а, Actual letter: ы
# Prediction: б, Actual letter: д
# Prediction: п, Actual letter: а
# Prediction: х, Actual letter: ъ
# Prediction: г, Actual letter: п
# Prediction: д, Actual letter: г
# Prediction: в, Actual letter: ь
# Prediction: г, Actual letter: п
# Prediction: к, Actual letter: х
# Prediction: и, Actual letter: м
# Prediction: с, Actual letter: о
# Prediction: и, Actual letter: н
# Prediction: ы, Actual letter: ц
# Prediction: н, Actual letter: ж
# Prediction: я, Actual letter: ю
# Prediction: л, Actual letter: ь
# Prediction: л, Actual letter: м
# Prediction: б, Actual letter: ъ
# Prediction: б, Actual letter: ё
# Prediction: ъ, Actual letter: ё
# Prediction: д, Actual letter: ф
# Prediction: ц, Actual letter: щ
# Prediction: г, Actual letter: ч
# Prediction: ё, Actual letter: б
# Prediction: ь, Actual letter: ъ
# Prediction: к, Actual letter: о
# Prediction: ж, Actual letter: т
# Prediction: м, Actual letter: н
# Prediction: ь, Actual letter: ъ
# Prediction: ж, Actual letter: н
# Prediction: х, Actual letter: з
# Prediction: ь, Actual letter: з
# Prediction: ж, Actual letter: ш
# Prediction: д, Actual letter: р
# Prediction: а, Actual letter: ж
# Prediction: ь, Actual letter: л
# Prediction: д, Actual letter: ф
# Prediction: й, Actual letter: в
# Prediction: е, Actual letter: с
# Prediction: щ, Actual letter: ш
# Prediction: к, Actual letter: р
# Prediction: ж, Actual letter: к
# Prediction: м, Actual letter: ш
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: д, Actual letter: б
# Prediction: в, Actual letter: ь
# Prediction: с, Actual letter: т
# Prediction: ч, Actual letter: е
# Prediction: ж, Actual letter: ф
# Prediction: м, Actual letter: ж
# Prediction: ж, Actual letter: и
# Prediction: с, Actual letter: в
# Prediction: н, Actual letter: п
# Prediction: х, Actual letter: г
# Prediction: з, Actual letter: ё
# Prediction: ъ, Actual letter: в
# Prediction: у, Actual letter: з
# Prediction: о, Actual letter: ю
# Prediction: щ, Actual letter: ц
# Prediction: ж, Actual letter: х
# Prediction: с, Actual letter: е
# Prediction: н, Actual letter: т
# Prediction: х, Actual letter: а
# Prediction: щ, Actual letter: ш
# Prediction: г, Actual letter: ч
# Prediction: щ, Actual letter: ш
# Prediction: м, Actual letter: ш
# Prediction: е, Actual letter: ё
# Prediction: е, Actual letter: п
# Prediction: д, Actual letter: у
# Prediction: т, Actual letter: е
# Prediction: в, Actual letter: у
# Prediction: д, Actual letter: з
# Prediction: д, Actual letter: р
# Prediction: д, Actual letter: у
# Prediction: г, Actual letter: ч
# Prediction: э, Actual letter: ё
# Prediction: ч, Actual letter: ъ
# Prediction: ь, Actual letter: с
# Prediction: ь, Actual letter: в
# Prediction: д, Actual letter: з
# Prediction: к, Actual letter: и
# Prediction: ь, Actual letter: ц
# Prediction: и, Actual letter: н
# Prediction: ы, Actual letter: я
# Prediction: з, Actual letter: у
# Prediction: е, Actual letter: о
# Prediction: з, Actual letter: ф
# Prediction: х, Actual letter: и
# Prediction: й, Actual letter: в
# Prediction: г, Actual letter: ч
# Prediction: ч, Actual letter: ы
# Prediction: е, Actual letter: ю
# Prediction: е, Actual letter: л
# Prediction: а, Actual letter: х
# Prediction: р, Actual letter: п
# Prediction: х, Actual letter: ъ
# Prediction: з, Actual letter: у
# Prediction: г, Actual letter: й
# Prediction: с, Actual letter: е
# Prediction: у, Actual letter: д
# Prediction: е, Actual letter: ё
# Prediction: ы, Actual letter: ч
# Prediction: в, Actual letter: и
# Prediction: ч, Actual letter: г
# Prediction: я, Actual letter: э
# Prediction: л, Actual letter: м
# Prediction: г, Actual letter: ы
# Prediction: э, Actual letter: ь
# Prediction: я, Actual letter: а
# Prediction: ю, Actual letter: ш
# Prediction: э, Actual letter: о
# Prediction: ч, Actual letter: ъ
# Prediction: е, Actual letter: к
# Prediction: м, Actual letter: о
# Prediction: з, Actual letter: с
# Prediction: й, Actual letter: т
# Prediction: ч, Actual letter: г
# Prediction: и, Actual letter: м
# Prediction: ц, Actual letter: щ
# Prediction: х, Actual letter: ъ
# Prediction: ц, Actual letter: ш
# Prediction: л, Actual letter: х
# Prediction: щ, Actual letter: ш
# Prediction: з, Actual letter: д
# Prediction: к, Actual letter: н
# Prediction: г, Actual letter: х
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: н
# Prediction: е, Actual letter: с
# Prediction: д, Actual letter: у
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: ы
# Prediction: я, Actual letter: п
# Prediction: е, Actual letter: к
# Prediction: ф, Actual letter: т
# Prediction: с, Actual letter: ь
# Prediction: ч, Actual letter: ъ
# Prediction: с, Actual letter: п
# Prediction: ъ, Actual letter: ц
# Prediction: у, Actual letter: д
# Prediction: ё, Actual letter: г
# Prediction: щ, Actual letter: ш
# Prediction: л, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: к, Actual letter: н
# Prediction: ж, Actual letter: т
# Prediction: ъ, Actual letter: ё
# Prediction: ф, Actual letter: х
# Prediction: ж, Actual letter: ш
# Prediction: ц, Actual letter: ч
# Prediction: л, Actual letter: о
# Prediction: ж, Actual letter: щ
# Prediction: х, Actual letter: ф
# Prediction: я, Actual letter: ь
# Prediction: е, Actual letter: ь
# Prediction: ы, Actual letter: и
# Prediction: ё, Actual letter: а
# Prediction: а, Actual letter: ю
# Prediction: ы, Actual letter: ш
# Prediction: е, Actual letter: с
# Prediction: к, Actual letter: ч
# Prediction: с, Actual letter: е
# Prediction: х, Actual letter: я
# Prediction: п, Actual letter: г
# Prediction: е, Actual letter: с
# Prediction: х, Actual letter: н
# Prediction: и, Actual letter: н
# Prediction: ж, Actual letter: л
# Prediction: л, Actual letter: я
# Prediction: ъ, Actual letter: д
# Prediction: ъ, Actual letter: ч
# Prediction: д, Actual letter: у
# Prediction: с, Actual letter: е
# Prediction: у, Actual letter: ф
# Prediction: ж, Actual letter: ч
# Prediction: я, Actual letter: а
# Prediction: х, Actual letter: ч
# Prediction: й, Actual letter: ч
# Prediction: х, Actual letter: ы
# Prediction: к, Actual letter: в
# Prediction: ч, Actual letter: г
# Prediction: л, Actual letter: и
# Prediction: ж, Actual letter: ш
# Prediction: и, Actual letter: ц
# Prediction: и, Actual letter: н
# Prediction: к, Actual letter: п
# Prediction: л, Actual letter: м
# Prediction: ё, Actual letter: в
# Prediction: р, Actual letter: к
# Prediction: в, Actual letter: е
# Prediction: й, Actual letter: т
# Prediction: ч, Actual letter: ъ
# Prediction: и, Actual letter: ц
# Prediction: в, Actual letter: е
# Prediction: ю, Actual letter: щ
# Prediction: у, Actual letter: ц
# Prediction: е, Actual letter: н
# Prediction: м, Actual letter: и
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: а
# Prediction: е, Actual letter: к
# Prediction: ь, Actual letter: в
# Prediction: ц, Actual letter: щ
# Prediction: л, Actual letter: и
# Prediction: с, Actual letter: ы
# Prediction: ж, Actual letter: к
# Prediction: д, Actual letter: ц
# Prediction: щ, Actual letter: ч
# Prediction: м, Actual letter: н
# Prediction: к, Actual letter: ы
# Prediction: ж, Actual letter: т
# Prediction: к, Actual letter: п
# Prediction: ш, Actual letter: ы
# Prediction: т, Actual letter: ш
# Prediction: н, Actual letter: т
# Prediction: х, Actual letter: к
# Prediction: й, Actual letter: з
# Prediction: з, Actual letter: б
# Prediction: щ, Actual letter: ю
# Prediction: щ, Actual letter: ц
# Prediction: к, Actual letter: ю
# Prediction: и, Actual letter: а
# Prediction: л, Actual letter: и
# Prediction: и, Actual letter: н
# Prediction: н, Actual letter: ч
# Prediction: й, Actual letter: з
# Prediction: щ, Actual letter: ц
# Prediction: и, Actual letter: ц
# Prediction: я, Actual letter: е
# Prediction: г, Actual letter: ъ
# Prediction: ж, Actual letter: м
# Prediction: о, Actual letter: й
# Prediction: ы, Actual letter: п
# Prediction: ь, Actual letter: в
# Prediction: в, Actual letter: ь
# Prediction: з, Actual letter: у
# Prediction: в, Actual letter: ь
# Prediction: л, Actual letter: и
# Prediction: н, Actual letter: ы
# Prediction: э, Actual letter: ь
# Prediction: ц, Actual letter: щ
# Prediction: х, Actual letter: э
# Prediction: ю, Actual letter: т
# Prediction: я, Actual letter: м
# Prediction: ф, Actual letter: щ
# Prediction: ъ, Actual letter: г
# Prediction: щ, Actual letter: т
# Prediction: ж, Actual letter: ы
# Prediction: ч, Actual letter: п
# Prediction: к, Actual letter: а
# Prediction: ш, Actual letter: м
# Prediction: м, Actual letter: ж
# Prediction: з, Actual letter: б
# Prediction: ж, Actual letter: н
# Prediction: ж, Actual letter: х
# Prediction: д, Actual letter: з
# Prediction: и, Actual letter: ц
# Prediction: ф, Actual letter: с
# Prediction: б, Actual letter: ф
# Prediction: н, Actual letter: и
# Prediction: щ, Actual letter: ш
# Prediction: ж, Actual letter: т
# Prediction: в, Actual letter: е
# Prediction: с, Actual letter: е
# Prediction: ш, Actual letter: т
# Prediction: г, Actual letter: х
# Prediction: е, Actual letter: с
# Prediction: я, Actual letter: э
# Prediction: к, Actual letter: п
# Prediction: ж, Actual letter: т
# Prediction: щ, Actual letter: ш
# Prediction: я, Actual letter: й
# Prediction: з, Actual letter: х
# Prediction: ч, Actual letter: ц
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: ч, Actual letter: я
# Prediction: г, Actual letter: ъ
# Prediction: л, Actual letter: к
# Prediction: в, Actual letter: ь
# Prediction: я, Actual letter: а
# Prediction: е, Actual letter: в
# Prediction: х, Actual letter: н
# Prediction: ч, Actual letter: г
# Prediction: и, Actual letter: а
# Prediction: е, Actual letter: ё
# Prediction: щ, Actual letter: ц
# Prediction: д, Actual letter: у
# Prediction: ё, Actual letter: д
# Prediction: ю, Actual letter: а
# Prediction: ё, Actual letter: б
# Prediction: х, Actual letter: ж
# Prediction: х, Actual letter: м
# Prediction: п, Actual letter: т
# Prediction: х, Actual letter: т
# Prediction: м, Actual letter: и
# Prediction: г, Actual letter: я
# Prediction: т, Actual letter: ю
# Prediction: д, Actual letter: у
# Prediction: о, Actual letter: й
# Prediction: в, Actual letter: ь
# Prediction: в, Actual letter: г
# Prediction: ф, Actual letter: щ
# Prediction: ф, Actual letter: ц
# Prediction: м, Actual letter: ш
# Prediction: к, Actual letter: н
# Prediction: ч, Actual letter: ъ
# Prediction: г, Actual letter: п
# Prediction: ц, Actual letter: и
# Prediction: к, Actual letter: п
# Prediction: а, Actual letter: г
# Prediction: б, Actual letter: к
# Prediction: д, Actual letter: о
# Prediction: л, Actual letter: в
# Prediction: в, Actual letter: х
# Prediction: д, Actual letter: з
# Prediction: к, Actual letter: е
# Prediction: в, Actual letter: г
# Prediction: д, Actual letter: л
# Prediction: ъ, Actual letter: г
# Prediction: ч, Actual letter: я
# Prediction: д, Actual letter: ф
# Prediction: ч, Actual letter: ц
# Prediction: с, Actual letter: ф
# Prediction: й, Actual letter: б
# Prediction: и, Actual letter: ч
# Prediction: ч, Actual letter: г
# Prediction: с, Actual letter: е
# Prediction: о, Actual letter: з
# Prediction: л, Actual letter: и
# Prediction: е, Actual letter: ё
# Prediction: д, Actual letter: ф
# Prediction: м, Actual letter: ш
# Prediction: я, Actual letter: м
# Prediction: щ, Actual letter: ц
# Prediction: х, Actual letter: ы
# Prediction: и, Actual letter: н
# Prediction: з, Actual letter: ж
# Prediction: к, Actual letter: ю
# Prediction: ъ, Actual letter: з
# Prediction: м, Actual letter: н
# Prediction: х, Actual letter: г
# Prediction: ё, Actual letter: б
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: й
# Prediction: е, Actual letter: в
# Prediction: м, Actual letter: х
# Prediction: б, Actual letter: ё
# Prediction: ы, Actual letter: ч
# Prediction: е, Actual letter: ё
# Prediction: ж, Actual letter: ы
# Prediction: и, Actual letter: а
# Prediction: ж, Actual letter: ч
# Prediction: ш, Actual letter: ж
# Prediction: г, Actual letter: ч
# Prediction: п, Actual letter: л
# Prediction: ж, Actual letter: л
# Prediction: н, Actual letter: и
# Prediction: к, Actual letter: а
# Prediction: е, Actual letter: х
# Prediction: ч, Actual letter: ъ
# Prediction: ы, Actual letter: к
# Prediction: х, Actual letter: ю
# Prediction: х, Actual letter: а
# Prediction: н, Actual letter: и
# Prediction: с, Actual letter: е
# Prediction: д, Actual letter: у
# Prediction: ъ, Actual letter: ё
# Prediction: т, Actual letter: ы
# Prediction: д, Actual letter: з
# Prediction: ж, Actual letter: т
# Prediction: д, Actual letter: ф
# Prediction: х, Actual letter: ф
# Prediction: ф, Actual letter: ю
# Prediction: д, Actual letter: ъ
# Accuracy: 0.9295278365045807, My Accuracy: 0.9295278365045807

# %%
print(X_train_reshaped[0])
print(X_additional_reshaped[0])
# Out:
# [[[0.4627451 ]
#   [0.47058824]
#   [0.47058824]
#   ...
#   [0.4627451 ]
#   [0.4627451 ]
#   [0.47058824]]
#
#  [[0.46666667]
#   [0.47058824]
#   [0.47058824]
#   ...
#   [0.46666667]
#   [0.4627451 ]
#   [0.46666667]]
#
#  [[0.4627451 ]
#   [0.47058824]
#   [0.46666667]
#   ...
#   [0.47058824]
#   [0.46666667]
#   [0.47058824]]
#
#  ...
#
#  [[0.50980392]
#   [0.51372549]
#   [0.50980392]
#   ...
#   [0.50980392]
#   [0.50588235]
#   [0.50980392]]
#
#  [[0.50588235]
#   [0.50980392]
#   [0.51372549]
#   ...
#   [0.50980392]
#   [0.51372549]
#   [0.50980392]]
#
#  [[0.51372549]
#   [0.50980392]
#   [0.50980392]
#   ...
#   [0.50980392]
#   [0.51372549]
#   [0.50980392]]]
# [[[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]
#
#  [[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]
#
#  [[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]
#
#  ...
#
#  [[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]
#
#  [[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]
#
#  [[6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]
#   ...
#   [6.03086294e-08]
#   [6.03086294e-08]
#   [6.03086294e-08]]]
